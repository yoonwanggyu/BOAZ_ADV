# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import json
import uuid
import tiktoken
from openai import OpenAI
import pinecone
from tqdm import tqdm
import os
from dotenv import load_dotenv
from pinecone import Pinecone

# Pinecone API Key & 환경 정보 가져오기
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")
PINECONE_ENV = os.getenv("PINECONE_ENV")

# %%
### 🔢 Tokenizer
tokenizer = tiktoken.encoding_for_model("gpt-3.5-turbo")

def num_tokens(text):
    return len(tokenizer.encode(text))

# ### 📥 1. JSON 로드
# with open("C:/Users/USER/Downloads/apm-20099.json", "r", encoding="utf-8") as f:
#     data = json.load(f)

# %%
import os
import json

# 폴더 경로 설정 (역슬래시 대신 슬래시 또는 r 문자열로 작성)
folder_path = r"C:/Users/USER/OneDrive/바탕 화면/내 자료/보아즈/ADV 플젝/증례보고pdf"

# 모든 json 파일을 리스트로 로드
data = []

for filename in os.listdir(folder_path):
    if filename.endswith(".json"):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, "r", encoding="utf-8") as f:
            try:
                json_data = json.load(f)
                data.append(json_data)
            except json.JSONDecodeError as e:
                print(f"⚠️ JSON 파싱 오류: {filename} - {e}")

# 이제 data에는 모든 json 파일의 내용이 리스트 형태로 저장됨

# %%
data[0]["merged_text"]
# Out:
# '신생아에서 발생한 기관내 삽관 후 기도 손상의 주술기 관리-증례 보고- Perioperative management of tracheal injuryfollowing endotracheal intubation in aneonate# -A case report- Tracheal injury in neonates is a rare but serious complication ofendotracheal intubation. The morbidity and mortality are associatedwith early recognition and adequate management. Herein, wereported a case of perioperative management of neonatal trachealinjury following multiple attempts at endotracheal intubation causedby unanticipated difficulty. (Anesth Pain Med 2017; 12: 52-55) Key Words: Complication, Endotracheal intubation, Neonate.소아에서 기관내 삽관의 합병증으로 기도 손상이 발생하는 경우는 드물지만, 치명적인 결과를 초래할 수 있으므로빠른 진단과 적절한 처치가 매우 중요하다. 특히 신생아는기도의 해부학적 특성상 기관내 삽관과 연관된 손상에 더욱 취약하다[1]. 저자들은 출생 당일 기관내 삽관의 어려움으로 인해 삽관을 반복하여 시도한 후 기도 손상이 발생하여 외과적 봉합을 시행한 환아를 경험하여 문헌 고찰과 함께 보고하고자 한다.제왕절개술로 출생한 제태 기간 36주 여자 환아(신장 48cm, 체중 2,980 g)가 출생 직후부터 청색증을 보이고 말초산소포화도가 85%로 측정되어 마스크로 보조호흡을 하면서산소포화도가 95% 정도로 유지되었으나 호흡수가 상승하면서 흉부 함몰을 보여 출생 당일에 본원으로 전원되어 신생아 중환자실에 입원하였다. 입원 당시 환아의 활동성은 양호하였으나 호흡수는 분당 80회이었으며 심한 흉부 함몰을보였고, 청진상 특이 사항은 없었으며 말초산소포화도(SpO2)는 82%이었다. 환아의 외형 상 특이 소견은 없었으며흉부 방사선 촬영에도 특이 소견은 보이지 않았다. 소아청소년과에서 신생아 일과성 빠른 호흡(transient tachypnea ofnewborn)의 추정 진단(impression) 하에 FIO2 0.3-0.4, 호기말양압(positive end-expiratory pressure, PEEP)을 6 cmH2O로 지속적 기도 양압(continuous positive airway pressure, CPAP)을적용하였으나
 마취시간은 50분이었다.수술 후 환아를 신생아 중환자실로 이송하였으며 진정제투여 하에 기계 환기를 적용하였으나 기관 튜브 유지에 어려움이 발생하여 수술 다음날 신생아 중환자실에서 기관절개술을 시행하였다. 증상이 호전되어 기계 환기를 계속하면서 수술 7일 째부터 자발 호흡 하에 경과를 관찰하였다. 이후 특별한 문제가 없다가 입원 22일에 우측에 기흉이 발생하여 흉관을 삽입하여 5일간 유지하였다. 입원 30일째에 전반적인 환아의 상태가 양호하고 특이 소견은 없었으나 보호자가 타원으로 전원을 원하여 퇴원하였다. 고찰 기도 손상은 기관내 삽관과 연관되어 발생하는 드물지만심각한 합병증으로 특히 신생아에서는 사망률이 높은 것으로 보고되고 있다[2-4]. 기관내 삽관으로 인한 손상은 누구에게나 발생할 수 있지만, 소아와 성인의 기도 차이로 인해소아의 경우는 기관내 삽관 시에 손상에 더 취약하다. 즉,소아는 기도가 좁으면서 가장 좁은 부위가 윤상 연골 부위이며, 윤상 연골의 해부학적 특성상 성인과는 다르게 윤상연골판(cricoid lamina)이 뒤쪽으로 기울어져 계란형의 입구와 원형의 출구로 이루어진 깔때기 모양을 하고 있다. 따라서 기관 튜브가 위치하는 공간이 입구에서는 안전하게 제공되더라도 출구에서는 그렇지 못할 수 있다[1]. 특히 신생아는 미성숙된 기도의 탄성이 높고 연골 사이막(inter-cartilagenous membrane)이 약해서 기도 파열에 더욱 취약할 수 있다[2].기관내 삽관 후의 기도 손상은 다양한 원인에 의해 발생할 수 있는데, 여기에는 기관 내관, 속침, 후두경에 의한 직접 손상, 반복적인 삽관 시도, 좋지 않은 자세, 머리와 목의과신전(excessive hyperextension), 부적절한 근이완, 시술자의경험 부족,  ...

# %%
! pip install openai --upgrade
# Out:
# Requirement already satisfied: openai in c:\users\user\anaconda3\anaconda\lib\site-packages (0.28.0)
# Collecting openai
#   Downloading openai-1.90.0-py3-none-any.whl (734 kB)
#      -------------------------------------- 734.6/734.6 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (3.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (2.10.6)
# Requirement already satisfied: tqdm>4 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (1.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\anaconda\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\anaconda\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.28.0
#     Uninstalling openai-0.28.0:
#       Successfully uninstalled openai-0.28.0
# Successfully installed openai-1.90.0

# %%
import openai
from langchain_openai import OpenAIEmbeddings

# OpenAI의 "text-embedding-3-small" 모델을 사용하여 임베딩을 생성
embeddings = OpenAIEmbeddings(model="text-embedding-3-small", openai_api_key=OPENAI_API_KEY)

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter

# OpenAI 임베딩 설정
embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",
    openai_api_key=OPENAI_API_KEY
)

# 청킹 설정
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    separators=["\n\n", "\n", ".", " ", ""]
)

# 전체 벡터 저장용 리스트
all_texts = []
all_vectors = []
all_metadata = []

for i, item in enumerate(data):
    text = item["merged_text"]
    
    # 청크 분리
    chunks = text_splitter.split_text(text)
    
    # 임베딩 생성
    vectors = embeddings.embed_documents(chunks)
    
    # 저장
    all_texts.extend(chunks)
    all_vectors.extend(vectors)
    all_metadata.extend([{"source": f"doc_{i}", "chunk": j} for j in range(len(chunks))])

# %%
# 조건에 따라 year 값을 설정하는 함수
def get_year_from_source(source):
    if source in [f"doc_{i}" for i in range(0, 6)]:
        return 2017
    elif source == "doc_6":
        return 2018
    elif source in ["doc_7", "doc_8"]:
        return 2019
    else:
        return None  # 예외 처리용 (혹시 source 값이 다를 경우)

# year 값 추가
for item in all_metadata:
    source = item.get("source")
    item["year"] = get_year_from_source(source)

# %%
# 1. 문서 ID와 파일명 매핑 테이블 (사진 기반 순서에 따라 수정)
doc_id_to_filename = {
    "doc_0": "APM-12-052",
    "doc_1": "APM-12-147",
    "doc_2": "APM-12-240",
    "doc_3": "APM-12-243",
    "doc_4": "APM-12-335",
    "doc_5": "APM-12-339",
    "doc_6": "APM-12-173",
    "doc_7": "APM-12-040",
    "doc_8": "APM-12-044"
}

# 2. 기존 메타데이터 예시
# all_metadata = [{'source': 'doc_0', 'chunk': 0}, {'source': 'doc_0', 'chunk': 1}, ...]

# 3. source 필드 매핑
for item in all_metadata:
    old_id = item["source"]
    if old_id in doc_id_to_filename:
        item["source"] = doc_id_to_filename[old_id]

# %%
for meta in all_metadata:
    meta["paper_title"] = meta.pop("source")

all_metadata
# Out:
# [{'chunk': 0, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 1, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 2, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 3, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 4, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 5, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 6, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 7, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 8, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 9, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 10, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 11, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 12, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 13, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 14, 'year': 2017, 'paper_title': 'APM-12-052'},
#  {'chunk': 0, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 1, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 2, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 3, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 4, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 5, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 6, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 7, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 8, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 9, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 10, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 11, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 12, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 13, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 14, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 15, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 16, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 17, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 18, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 19, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 20, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 21, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 22, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 23, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 24, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 25, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 26, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 27, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 28, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 29, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 30, 'year': 2017, 'paper_title': 'APM-12-147'},
#  {'chunk': 0, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 1, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 2, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 3, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 4, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 5, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 6, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 7, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 8, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 9, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 10, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 11, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 12, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 13, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 14, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 15, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 16, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 17, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 18, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 19, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 20, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 21, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 22, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 23, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 24, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 25, 'year': 2017, 'paper_title': 'APM-12-240'},
#  {'chunk': 0, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 1, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 2, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 3, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 4, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 5, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 6, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 7, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 8, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 9, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 10, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 11, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 12, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 13, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 14, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 15, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 16, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 17, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 18, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 19, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 20, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 21, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 22, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 23, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 24, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 25, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 26, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 27, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 28, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 29, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 30, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 31, 'year': 2017, 'paper_title': 'APM-12-243'},
#  {'chunk': 0, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 1, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 2, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 3, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 4, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 5, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 6, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 7, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 8, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 9, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 10, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 11, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 12, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 13, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 14, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 15, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 16, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 17, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 18, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 19, 'year': 2017, 'paper_title': 'APM-12-335'},
#  {'chunk': 0, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 1, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 2, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 3, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 4, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 5, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 6, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 7, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 8, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 9, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 10, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 11, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 12, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 13, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 14, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 15, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 16, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 17, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 18, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 19, 'year': 2017, 'paper_title': 'APM-12-339'},
#  {'chunk': 0, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 1, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 2, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 3, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 4, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 5, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 6, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 7, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 8, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 9, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 10, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 11, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 12, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 13, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 14, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 15, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 16, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 17, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 18, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 19, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 20, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 21, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 22, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 23, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 24, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 25, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 26, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 27, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 28, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 29, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 30, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 31, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 32, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 33, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 34, 'year': 2018, 'paper_title': 'APM-12-173'},
#  {'chunk': 0, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 1, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 2, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 3, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 4, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 5, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 6, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 7, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 8, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 9, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 10, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 11, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 12, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 13, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 14, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 15, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 16, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 17, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 18, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 19, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 20, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 21, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 22, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 23, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 24, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 25, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 26, 'year': 2019, 'paper_title': 'APM-12-040'},
#  {'chunk': 0, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 1, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 2, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 3, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 4, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 5, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 6, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 7, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 8, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 9, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 10, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 11, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 12, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 13, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 14, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 15, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 16, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 17, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 18, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 19, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 20, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 21, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 22, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 23, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 24, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 25, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 26, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 27, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 28, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 29, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 30, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 31, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 32, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 33, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 34, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 35, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 36, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 37, 'year': 2019, 'paper_title': 'APM-12-044'},
#  {'chunk': 38, 'year': 2019, 'paper_title': 'APM-12-044'}]

# %%
import pinecone
from tqdm import tqdm  # 진행 상황 보기 용도
import os
from pinecone import Pinecone, ServerlessSpec

# 인덱스 이름 지정
PINECONE_INDEX_NAME = 'boaz01'

# Initialize clients
openai_client = OpenAI(api_key=OPENAI_API_KEY)
#pinecone.init(api_key=PINECONE_API_KEY, environment=PINECONE_ENV)

# Pinecone 인스턴스 생성
pc = Pinecone(api_key=PINECONE_API_KEY)

# 인덱스가 존재하는지 확인 후 연결
existing_indexes = [index["name"] for index in pc.list_indexes()]
if PINECONE_INDEX_NAME not in existing_indexes:
    raise ValueError(f"❌ '{PINECONE_INDEX_NAME}' 인덱스가 존재하지 않습니다. Pinecone에서 생성해주세요!")

# 인덱스 연결
index = pc.Index(PINECONE_INDEX_NAME)

# 업서트할 벡터 묶음 생성 (id, vector, metadata 포함)
to_upsert = []
for i, (vec, meta) in enumerate(zip(all_vectors, all_metadata)):
    to_upsert.append((f"chunk_{i}", vec, meta))

# 배치로 업서트 (100개씩)
batch_size = 100
for i in tqdm(range(0, len(to_upsert), batch_size)):
    batch = to_upsert[i:i+batch_size]
    index.upsert(vectors=batch)
# Out:
# 100%|██████████| 3/3 [00:08<00:00,  2.75s/it]

# %% [markdown]
# --------------여기 밑에는 522버전이고, 위에는 621 다은이 json가지고 증례보고 임베딩생성성

# %% [markdown]
# ### document생성

# %%
data_list = data['elements']

# %%
for element in data_list:
    print(element)
# Out:
# {'category': 'heading1', 'content': {'html': "<h1 id='0' style='font-size:20px'>apm<br>ANESTHESIA & PAIN MEDICINE</h1>", 'markdown': '# apm\nANESTHESIA & PAIN MEDICINE', 'text': 'apm\nANESTHESIA & PAIN MEDICINE'}, 'coordinates': [{'x': 0.0427, 'y': 0.0273}, {'x': 0.2725, 'y': 0.0273}, {'x': 0.2725, 'y': 0.0953}, {'x': 0.0427, 'y': 0.0953}], 'id': 0, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<br><p id='1' data-category='paragraph' style='font-size:14px'>Check for<br>updates</p>", 'markdown': 'Check for\nupdates', 'text': 'Check for\nupdates'}, 'coordinates': [{'x': 0.8787, 'y': 0.0481}, {'x': 0.9184, 'y': 0.0481}, {'x': 0.9184, 'y': 0.0615}, {'x': 0.8787, 'y': 0.0615}], 'id': 1, 'page': 1}
# {'category': 'heading1', 'content': {'html': "<br><h1 id='2' style='font-size:20px'>Case Report</h1>", 'markdown': '# Case Report', 'text': 'Case Report'}, 'coordinates': [{'x': 0.7266, 'y': 0.0715}, {'x': 0.8604, 'y': 0.0715}, {'x': 0.8604, 'y': 0.0938}, {'x': 0.7266, 'y': 0.0938}], 'id': 2, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<br><p id='3' data-category='paragraph' style='font-size:14px'>Anesth Pain Med 2021;16:273-278<br>https://doi.org/10.17085/apm.20099<br>pISSN 1975-5171 · eISSN 2383-7977</p>", 'markdown': 'Anesth Pain Med 2021;16:273-278\nhttps://doi.org/10.17085/apm.20099\npISSN 1975-5171 · eISSN 2383-7977', 'text': 'Anesth Pain Med 2021;16:273-278\nhttps://doi.org/10.17085/apm.20099\npISSN 1975-5171 · eISSN 2383-7977'}, 'coordinates': [{'x': 0.3299, 'y': 0.0631}, {'x': 0.553, 'y': 0.0631}, {'x': 0.553, 'y': 0.101}, {'x': 0.3299, 'y': 0.101}], 'id': 3, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<p id='4' data-category='paragraph' style='font-size:16px'>Received December 28, 2020<br>Revised March 10, 2021<br>Accepted March 14, 2021</p>", 'markdown': 'Received December 28, 2020\nRevised March 10, 2021\nAccepted March 14, 2021', 'text': 'Received December 28, 2020\nRevised March 10, 2021\nAccepted March 14, 2021'}, 'coordinates': [{'x': 0.0787, 'y': 0.3299}, {'x': 0.269, 'y': 0.3299}, {'x': 0.269, 'y': 0.3745}, {'x': 0.0787, 'y': 0.3745}], 'id': 4, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<p id='5' data-category='paragraph' style='font-size:16px'>Corresponding author</p>", 'markdown': 'Corresponding author', 'text': 'Corresponding author'}, 'coordinates': [{'x': 0.0791, 'y': 0.4804}, {'x': 0.2182, 'y': 0.4804}, {'x': 0.2182, 'y': 0.4923}, {'x': 0.0791, 'y': 0.4923}], 'id': 5, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<br><p id='6' data-category='paragraph' style='font-size:16px'>Hee-Soo Kim, M.D., Ph.D.<br>Department of Anesthesiology and<br>Pain Medicine, Seoul National<br>University Hospital, 101 Daehak-ro,<br>Jongno-gu, Seoul 03080, Korea<br>Tel: 82-2-2072-3659<br>Fax: 82-2-745-5587<br>E-mail: dami0605@snu.ac.kr</p>", 'markdown': 'Hee-Soo Kim, M.D., Ph.D.\nDepartment of Anesthesiology and\nPain Medicine, Seoul National\nUniversity Hospital, 101 Daehak-ro,\nJongno-gu, Seoul 03080, Korea\nTel: 82-2-2072-3659\nFax: 82-2-745-5587\nE-mail: dami0605@snu.ac.kr', 'text': 'Hee-Soo Kim, M.D., Ph.D.\nDepartment of Anesthesiology and\nPain Medicine, Seoul National\nUniversity Hospital, 101 Daehak-ro,\nJongno-gu, Seoul 03080, Korea\nTel: 82-2-2072-3659\nFax: 82-2-745-5587\nE-mail: dami0605@snu.ac.kr'}, 'coordinates': [{'x': 0.0782, 'y': 0.4869}, {'x': 0.294, 'y': 0.4869}, {'x': 0.294, 'y': 0.613}, {'x': 0.0782, 'y': 0.613}], 'id': 6, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<p id='7' data-category='paragraph' style='font-size:16px'>This study was presented in the<br>Korean Society of Pediatric Anesthesia<br>Annual Meeting, 17 October 2020,<br>online.</p>", 'markdown': 'This study was presented in the\nKorean Society of Pediatric Anesthesia\nAnnual Meeting, 17 October 2020,\nonline.', 'text': 'This study was presented in the\nKorean Society of Pediatric Anesthesia\nAnnual Meeting, 17 October 2020,\nonline.'}, 'coordinates': [{'x': 0.0779, 'y': 0.6308}, {'x': 0.3118, 'y': 0.6308}, {'x': 0.3118, 'y': 0.6888}, {'x': 0.0779, 'y': 0.6888}], 'id': 7, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<p id='8' data-category='paragraph' style='font-size:16px'>Central venous catheterization is frequently performed<br>during general anesthesia, mainly for fluid administration<br>and monitoring of central venous pressure. In addition, the<br>need for frequent blood sampling can also be a reason for<br>central venous catheterization to reduce the pain or fear of<br>needle insertion. Since pediatric patients with moyamoya<br>disease (MMD) are at risk ofischemic attack when crying or<br>undergoing physical or emotional stress, a central venous</p>", 'markdown': 'Central venous catheterization is frequently performed\nduring general anesthesia, mainly for fluid administration\nand monitoring of central venous pressure. In addition, the\nneed for frequent blood sampling can also be a reason for\ncentral venous catheterization to reduce the pain or fear of\nneedle insertion. Since pediatric patients with moyamoya\ndisease (MMD) are at risk ofischemic attack when crying or\nundergoing physical or emotional stress, a central venous', 'text': 'Central venous catheterization is frequently performed\nduring general anesthesia, mainly for fluid administration\nand monitoring of central venous pressure. In addition, the\nneed for frequent blood sampling can also be a reason for\ncentral venous catheterization to reduce the pain or fear of\nneedle insertion. Since pediatric patients with moyamoya\ndisease (MMD) are at risk ofischemic attack when crying or\nundergoing physical or emotional stress, a central venous'}, 'coordinates': [{'x': 0.0773, 'y': 0.7309}, {'x': 0.4844, 'y': 0.7309}, {'x': 0.4844, 'y': 0.8722}, {'x': 0.0773, 'y': 0.8722}], 'id': 8, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<p id='12' data-category='paragraph' style='font-size:16px'>Background: Pediatric patients with moyamoya disease are vulnerable to ischemic attacks<br>following physical or emotional stress, such as those experienced during blood sampling. A<br>central venous catheter might be beneficial for blood sampling, and a peripherally inserted<br>central catheter (PICC) is a considerable option for central venous access. However, PICC in-<br>sertion during anesthetic management is relatively rare.</p>", 'markdown': 'Background: Pediatric patients with moyamoya disease are vulnerable to ischemic attacks\nfollowing physical or emotional stress, such as those experienced during blood sampling. A\ncentral venous catheter might be beneficial for blood sampling, and a peripherally inserted\ncentral catheter (PICC) is a considerable option for central venous access. However, PICC in-\nsertion during anesthetic management is relatively rare.', 'text': 'Background: Pediatric patients with moyamoya disease are vulnerable to ischemic attacks\nfollowing physical or emotional stress, such as those experienced during blood sampling. A\ncentral venous catheter might be beneficial for blood sampling, and a peripherally inserted\ncentral catheter (PICC) is a considerable option for central venous access. However, PICC in-\nsertion during anesthetic management is relatively rare.'}, 'coordinates': [{'x': 0.3303, 'y': 0.4176}, {'x': 0.9218, 'y': 0.4176}, {'x': 0.9218, 'y': 0.4962}, {'x': 0.3303, 'y': 0.4962}], 'id': 12, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<br><p id='13' data-category='paragraph' style='font-size:16px'>Case: Thirty cases of ultrasound-guided PICC insertion were performed in children undergo-<br>ing surgery for moyamoya disease after anesthetic induction. Positioning was successful in<br>22 cases, and 5 were malpositioned. In three cases, the peripheral insertion failed. Adjust-<br>ment of the insertion depth was performed in nine cases. No complications related to cath-<br>eterization were observed during the procedure or the catheter indwelling period.</p>", 'markdown': 'Case: Thirty cases of ultrasound-guided PICC insertion were performed in children undergo-\ning surgery for moyamoya disease after anesthetic induction. Positioning was successful in\n22 cases, and 5 were malpositioned. In three cases, the peripheral insertion failed. Adjust-\nment of the insertion depth was performed in nine cases. No complications related to cath-\neterization were observed during the procedure or the catheter indwelling period.', 'text': 'Case: Thirty cases of ultrasound-guided PICC insertion were performed in children undergo-\ning surgery for moyamoya disease after anesthetic induction. Positioning was successful in\n22 cases, and 5 were malpositioned. In three cases, the peripheral insertion failed. Adjust-\nment of the insertion depth was performed in nine cases. No complications related to cath-\neterization were observed during the procedure or the catheter indwelling period.'}, 'coordinates': [{'x': 0.3322, 'y': 0.5026}, {'x': 0.921, 'y': 0.5026}, {'x': 0.921, 'y': 0.5829}, {'x': 0.3322, 'y': 0.5829}], 'id': 13, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<br><p id='14' data-category='paragraph' style='font-size:16px'>Conclusions: We report the successful use of PICC in children undergoing surgery for moy-<br>amoya disease with a considerable success rate and low incidence of malpositioning or<br>complications.</p>", 'markdown': 'Conclusions: We report the successful use of PICC in children undergoing surgery for moy-\namoya disease with a considerable success rate and low incidence of malpositioning or\ncomplications.', 'text': 'Conclusions: We report the successful use of PICC in children undergoing surgery for moy-\namoya disease with a considerable success rate and low incidence of malpositioning or\ncomplications.'}, 'coordinates': [{'x': 0.3292, 'y': 0.5887}, {'x': 0.916, 'y': 0.5887}, {'x': 0.916, 'y': 0.6347}, {'x': 0.3292, 'y': 0.6347}], 'id': 14, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<p id='15' data-category='paragraph' style='font-size:16px'>Keywords: Children; General anesthesia; Central venous catheterization; Moyamoya dis-<br>ease; Neurosurgery; Ultrasonography.</p>", 'markdown': 'Keywords: Children; General anesthesia; Central venous catheterization; Moyamoya dis-\nease; Neurosurgery; Ultrasonography.', 'text': 'Keywords: Children; General anesthesia; Central venous catheterization; Moyamoya dis-\nease; Neurosurgery; Ultrasonography.'}, 'coordinates': [{'x': 0.3307, 'y': 0.6529}, {'x': 0.9189, 'y': 0.6529}, {'x': 0.9189, 'y': 0.6849}, {'x': 0.3307, 'y': 0.6849}], 'id': 15, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<p id='16' data-category='paragraph' style='font-size:16px'>catheter would be helpful for postoperative blood sampling<br>or fluid management to prevent these events.</p>", 'markdown': 'catheter would be helpful for postoperative blood sampling\nor fluid management to prevent these events.', 'text': 'catheter would be helpful for postoperative blood sampling\nor fluid management to prevent these events.'}, 'coordinates': [{'x': 0.5157, 'y': 0.7315}, {'x': 0.9201, 'y': 0.7315}, {'x': 0.9201, 'y': 0.7632}, {'x': 0.5157, 'y': 0.7632}], 'id': 16, 'page': 1}
# {'category': 'paragraph', 'content': {'html': "<br><p id='17' data-category='paragraph' style='font-size:16px'>A peripherally inserted central catheter (PICC) is a good<br>option for central venous access [1] with good compliance,<br>low complication rate [2,3], and readiness for ambulation af-<br>ter surgery, compared to the internal jugular or subclavian<br>veins. However, it is rarely selected by anesthesiologists in<br>the operating room. While PICC can be inserted at the bed-</p>", 'markdown': 'A peripherally inserted central catheter (PICC) is a good\noption for central venous access [1] with good compliance,\nlow complication rate [2,3], and readiness for ambulation af-\nter surgery, compared to the internal jugular or subclavian\nveins. However, it is rarely selected by anesthesiologists in\nthe operating room. While PICC can be inserted at the bed-', 'text': 'A peripherally inserted central catheter (PICC) is a good\noption for central venous access [1] with good compliance,\nlow complication rate [2,3], and readiness for ambulation af-\nter surgery, compared to the internal jugular or subclavian\nveins. However, it is rarely selected by anesthesiologists in\nthe operating room. While PICC can be inserted at the bed-'}, 'coordinates': [{'x': 0.5166, 'y': 0.7668}, {'x': 0.9212, 'y': 0.7668}, {'x': 0.9212, 'y': 0.8715}, {'x': 0.5166, 'y': 0.8715}], 'id': 17, 'page': 1}
# {'category': 'footer', 'content': {'html': "<footer id='18' style='font-size:18px'>273</footer>", 'markdown': '273', 'text': '273'}, 'coordinates': [{'x': 0.4811, 'y': 0.946}, {'x': 0.5179, 'y': 0.946}, {'x': 0.5179, 'y': 0.9602}, {'x': 0.4811, 'y': 0.9602}], 'id': 18, 'page': 1}
# {'category': 'footer', 'content': {'html': "<br><footer id='19' style='font-size:22px'>KSPA</footer>", 'markdown': 'KSPA', 'text': 'KSPA'}, 'coordinates': [{'x': 0.9641, 'y': 0.3115}, {'x': 0.9835, 'y': 0.3115}, {'x': 0.9835, 'y': 0.344}, {'x': 0.9641, 'y': 0.344}], 'id': 19, 'page': 1}
# {'category': 'footnote', 'content': {'html': "<p id='20' data-category='footnote' style='font-size:14px'>This is an Open Access article distributed under the terms of the Creative Commons Attribution Non-Commercial License (http://crativecommons.org/icerses/by-ng/40) which permits<br>unrestricted non-commercial use, distribution, and reproduction in any medium, provided the original workis properly cited.<br>Copyright Ⓒ the Korean Society of Anesthesiologists, 2021</p>", 'markdown': 'This is an Open Access article distributed under the terms of the Creative Commons Attribution Non-Commercial License (http://crativecommons.org/icerses/by-ng/40) which permits\nunrestricted non-commercial use, distribution, and reproduction in any medium, provided the original workis properly cited.\nCopyright Ⓒ the Korean Society of Anesthesiologists, 2021', 'text': 'This is an Open Access article distributed under the terms of the Creative Commons Attribution Non-Commercial License (http://crativecommons.org/icerses/by-ng/40) which permits\nunrestricted non-commercial use, distribution, and reproduction in any medium, provided the original workis properly cited.\nCopyright Ⓒ the Korean Society of Anesthesiologists, 2021'}, 'coordinates': [{'x': 0.0789, 'y': 0.8947}, {'x': 0.9218, 'y': 0.8947}, {'x': 0.9218, 'y': 0.9275}, {'x': 0.0789, 'y': 0.9275}], 'id': 20, 'page': 1}
# {'category': 'header', 'content': {'html': "<header id='21' style='font-size:14px'>Anesth Pain Med Vol. 16 No. 3</header>", 'markdown': 'Anesth Pain Med Vol. 16 No. 3', 'text': 'Anesth Pain Med Vol. 16 No. 3'}, 'coordinates': [{'x': 0.4018, 'y': 0.0473}, {'x': 0.5963, 'y': 0.0473}, {'x': 0.5963, 'y': 0.0607}, {'x': 0.4018, 'y': 0.0607}], 'id': 21, 'page': 2}
# {'category': 'paragraph', 'content': {'html': "<p id='22' data-category='paragraph' style='font-size:16px'>side or under fluoroscopic guidance prior to surgery for<br>adults, PICC insertion for pediatric patients is not easy, and<br>they require sedation for the procedure in most cases. Under<br>general anesthesia, ultrasound is readily applicable to pedi-<br>atric patients without causing radiation hazards compared<br>to fluoroscopy, which is frequently used as a guide for PICC<br>insertion.</p>", 'markdown': 'side or under fluoroscopic guidance prior to surgery for\nadults, PICC insertion for pediatric patients is not easy, and\nthey require sedation for the procedure in most cases. Under\ngeneral anesthesia, ultrasound is readily applicable to pedi-\natric patients without causing radiation hazards compared\nto fluoroscopy, which is frequently used as a guide for PICC\ninsertion.', 'text': 'side or under fluoroscopic guidance prior to surgery for\nadults, PICC insertion for pediatric patients is not easy, and\nthey require sedation for the procedure in most cases. Under\ngeneral anesthesia, ultrasound is readily applicable to pedi-\natric patients without causing radiation hazards compared\nto fluoroscopy, which is frequently used as a guide for PICC\ninsertion.'}, 'coordinates': [{'x': 0.0772, 'y': 0.088}, {'x': 0.4832, 'y': 0.088}, {'x': 0.4832, 'y': 0.209}, {'x': 0.0772, 'y': 0.209}], 'id': 22, 'page': 2}
# {'category': 'paragraph', 'content': {'html': "<br><p id='23' data-category='paragraph' style='font-size:14px'>We recently introduced a policy to insert the PICC under<br>ultrasound guidance after induction of general anesthesia in<br>pediatric patients undergoing surgery for MMD. We report<br>our cases along with a summary of the success and compli-<br>cation rates.</p>", 'markdown': 'We recently introduced a policy to insert the PICC under\nultrasound guidance after induction of general anesthesia in\npediatric patients undergoing surgery for MMD. We report\nour cases along with a summary of the success and compli-\ncation rates.', 'text': 'We recently introduced a policy to insert the PICC under\nultrasound guidance after induction of general anesthesia in\npediatric patients undergoing surgery for MMD. We report\nour cases along with a summary of the success and compli-\ncation rates.'}, 'coordinates': [{'x': 0.0772, 'y': 0.2139}, {'x': 0.4837, 'y': 0.2139}, {'x': 0.4837, 'y': 0.2994}, {'x': 0.0772, 'y': 0.2994}], 'id': 23, 'page': 2}
# {'category': 'heading1', 'content': {'html': "<h1 id='24' style='font-size:22px'>CASE REPORT</h1>", 'markdown': '# CASE REPORT', 'text': 'CASE REPORT'}, 'coordinates': [{'x': 0.2098, 'y': 0.3197}, {'x': 0.3515, 'y': 0.3197}, {'x': 0.3515, 'y': 0.3386}, {'x': 0.2098, 'y': 0.3386}], 'id': 24, 'page': 2}
# {'category': 'heading1', 'content': {'html': "<h1 id='25' style='font-size:20px'>Ethics statement</h1>", 'markdown': '# Ethics statement', 'text': 'Ethics statement'}, 'coordinates': [{'x': 0.0786, 'y': 0.3559}, {'x': 0.219, 'y': 0.3559}, {'x': 0.219, 'y': 0.3723}, {'x': 0.0786, 'y': 0.3723}], 'id': 25, 'page': 2}
# {'category': 'paragraph', 'content': {'html': "<p id='26' data-category='paragraph' style='font-size:14px'>This report was approved by the Institutional Review<br>Board of Seoul National University Hospital (no. 2004-231-<br>1119), and the requirement for obtaining informed consent<br>was waived. The reason for the exemption from consent was<br>as follows: First, obtaining informed consent from the pa-<br>tients was not feasible because they had already been dis-<br>charged from the hospital at the moment we started to re-<br>view the cases. Second, there was no reason to assume dis-<br>agreement regarding the use of data from the patients, and<br>there was no chance of affecting any of the patients' treat-<br>ment or prognosis.</p>", 'markdown': "This report was approved by the Institutional Review\nBoard of Seoul National University Hospital (no. 2004-231-\n1119), and the requirement for obtaining informed consent\nwas waived. The reason for the exemption from consent was\nas follows: First, obtaining informed consent from the pa-\ntients was not feasible because they had already been dis-\ncharged from the hospital at the moment we started to re-\nview the cases. Second, there was no reason to assume dis-\nagreement regarding the use of data from the patients, and\nthere was no chance of affecting any of the patients' treat-\nment or prognosis.", 'text': "This report was approved by the Institutional Review\nBoard of Seoul National University Hospital (no. 2004-231-\n1119), and the requirement for obtaining informed consent\nwas waived. The reason for the exemption from consent was\nas follows: First, obtaining informed consent from the pa-\ntients was not feasible because they had already been dis-\ncharged from the hospital at the moment we started to re-\nview the cases. Second, there was no reason to assume dis-\nagreement regarding the use of data from the patients, and\nthere was no chance of affecting any of the patients' treat-\nment or prognosis."}, 'coordinates': [{'x': 0.0775, 'y': 0.3917}, {'x': 0.4837, 'y': 0.3917}, {'x': 0.4837, 'y': 0.5854}, {'x': 0.0775, 'y': 0.5854}], 'id': 26, 'page': 2}
# {'category': 'heading1', 'content': {'html': "<h1 id='27' style='font-size:22px'>Study population</h1>", 'markdown': '# Study population', 'text': 'Study population'}, 'coordinates': [{'x': 0.0781, 'y': 0.6058}, {'x': 0.2233, 'y': 0.6058}, {'x': 0.2233, 'y': 0.6235}, {'x': 0.0781, 'y': 0.6235}], 'id': 27, 'page': 2}
# {'category': 'paragraph', 'content': {'html': "<p id='28' data-category='paragraph' style='font-size:14px'>We reviewed 30 cases of ultrasound-guided PICC inser-<br>tion after anesthetic induction in pediatric patients under-<br>going surgery for MMD between January 2020 and April<br>2020. The baseline characteristics are shown in Table 1. Sev-<br>enteen (56.7%) patients had previously undergone neuro-<br>surgery with central venous catheterization using one of the<br>internal jugular veins. Patients with connective tissue dis-<br>ease or vascular disease other than MMD, any skin lesion in<br>the upper extremity, and unstable vital signs on anesthetic<br>induction were excluded from the PICC insertion.</p>", 'markdown': 'We reviewed 30 cases of ultrasound-guided PICC inser-\ntion after anesthetic induction in pediatric patients under-\ngoing surgery for MMD between January 2020 and April\n2020. The baseline characteristics are shown in Table 1. Sev-\nenteen (56.7%) patients had previously undergone neuro-\nsurgery with central venous catheterization using one of the\ninternal jugular veins. Patients with connective tissue dis-\nease or vascular disease other than MMD, any skin lesion in\nthe upper extremity, and unstable vital signs on anesthetic\ninduction were excluded from the PICC insertion.', 'text': 'We reviewed 30 cases of ultrasound-guided PICC inser-\ntion after anesthetic induction in pediatric patients under-\ngoing surgery for MMD between January 2020 and April\n2020. The baseline characteristics are shown in Table 1. Sev-\nenteen (56.7%) patients had previously undergone neuro-\nsurgery with central venous catheterization using one of the\ninternal jugular veins. Patients with connective tissue dis-\nease or vascular disease other than MMD, any skin lesion in\nthe upper extremity, and unstable vital signs on anesthetic\ninduction were excluded from the PICC insertion.'}, 'coordinates': [{'x': 0.0775, 'y': 0.6413}, {'x': 0.4834, 'y': 0.6413}, {'x': 0.4834, 'y': 0.8169}, {'x': 0.0775, 'y': 0.8169}], 'id': 28, 'page': 2}
# {'category': 'heading1', 'content': {'html': "<h1 id='29' style='font-size:20px'>Catheter insertion technique</h1>", 'markdown': '# Catheter insertion technique', 'text': 'Catheter insertion technique'}, 'coordinates': [{'x': 0.0786, 'y': 0.8375}, {'x': 0.3162, 'y': 0.8375}, {'x': 0.3162, 'y': 0.8552}, {'x': 0.0786, 'y': 0.8552}], 'id': 29, 'page': 2}
# {'category': 'paragraph', 'content': {'html': "<p id='30' data-category='paragraph' style='font-size:16px'>After conventional induction of general anesthesia, the<br>patient was positioned for PICC insertion in the supine posi-<br>tion, and the right upper arm was abducted [4]. After posi-</p>", 'markdown': 'After conventional induction of general anesthesia, the\npatient was positioned for PICC insertion in the supine posi-\ntion, and the right upper arm was abducted [4]. After posi-', 'text': 'After conventional induction of general anesthesia, the\npatient was positioned for PICC insertion in the supine posi-\ntion, and the right upper arm was abducted [4]. After posi-'}, 'coordinates': [{'x': 0.0776, 'y': 0.8734}, {'x': 0.4833, 'y': 0.8734}, {'x': 0.4833, 'y': 0.9255}, {'x': 0.0776, 'y': 0.9255}], 'id': 30, 'page': 2}
# {'category': 'paragraph', 'content': {'html': "<br><p id='31' data-category='paragraph' style='font-size:14px'>tioning, the basilic or cephalic vein was evaluated using an<br>ultrasound device (E-CUBE i7, Alpinion Medical Systems<br>Co., Ltd., Korea or Sonosite X-Porte, Fujifilm Sonosite, Inc.,<br>USA) to select the venipuncture site. If the basilic vein was<br>selected, the elbow was flexed at 90°, while it was extended<br>to the cephalic vein
# {'category': 'paragraph', 'content': {'html': "<p id='32' data-category='paragraph' style='font-size:14px'>Table 1. Baseline Characteristics of Subjects, Selected Veins, and<br>Catheter Size for Insertion of a Peripherally-inserted Central Catheter</p>", 'markdown': 'Table 1. Baseline Characteristics of Subjects, Selected Veins, and\nCatheter Size for Insertion of a Peripherally-inserted Central Catheter', 'text': 'Table 1. Baseline Characteristics of Subjects, Selected Veins, and\nCatheter Size for Insertion of a Peripherally-inserted Central Catheter'}, 'coordinates': [{'x': 0.5153, 'y': 0.6309}, {'x': 0.9207, 'y': 0.6309}, {'x': 0.9207, 'y': 0.659}, {'x': 0.5153, 'y': 0.659}], 'id': 32, 'page': 2}
# {'base64_encoding': '...', 'category': 'table', 'content': {'html': "<br><table id='33' style='font-size:14px'><thead><tr><td>Characteristic</td><td>Value</td></tr></thead><tbody><tr><td>Sex (M/F)</td><td>20/10</td></tr><tr><td>Age (yr)</td><td>7.5 (6, 9)</td></tr><tr><td>Height (cm)</td><td>124.0 (115.7, 146.2)</td></tr><tr><td>Weight (kg)</td><td>28.4 (21.7, 46.6)</td></tr><tr><td>Selected vein</td><td></td></tr><tr><td>Basilic</td><td>21 (70.0)</td></tr><tr><td>Cephalic</td><td>6 (20.0)</td></tr><tr><td>Failure for both</td><td>3 (10.0)</td></tr><tr><td>Vein diameter (mm)</td><td>4.0 土 0.9</td></tr><tr><td>Vein depth (mm)</td><td>5.4 (4.1, 8.5)</td></tr><tr><td>Catheter size (Fr)</td><td></td></tr><tr><td>3</td><td>26 (86.7)</td></tr><tr><td>4</td><td>4 (13.3)</td></tr></tbody></table>", 'markdown': '| Characteristic | Value |\n| --- | --- |\n| Sex (M/F) | 20/10 |\n| Age (yr) | 7.5 (6, 9) |\n| Height (cm) | 124.0 (115.7, 146.2) |\n| Weight (kg) | 28.4 (21.7, 46.6) |\n| Selected vein |  |\n| Basilic | 21 (70.0) |\n| Cephalic | 6 (20.0) |\n| Failure for both | 3 (10.0) |\n| Vein diameter (mm) | 4.0 土 0.9 |\n| Vein depth (mm) | 5.4 (4.1, 8.5) |\n| Catheter size (Fr) |  |\n| 3 | 26 (86.7) |\n| 4 | 4 (13.3) |\n', 'text': 'Characteristic Value\n Sex (M/F) 20/10\n Age (yr) 7.5 (6, 9)\n Height (cm) 124.0 (115.7, 146.2)\n Weight (kg) 28.4 (21.7, 46.6)\n Selected vein \n Basilic 21 (70.0)\n Cephalic 6 (20.0)\n Failure for both 3 (10.0)\n Vein diameter (mm) 4.0 土 0.9\n Vein depth (mm) 5.4 (4.1, 8.5)\n Catheter size (Fr) \n 3 26 (86.7)\n 4 4 (13.3)'}, 'coordinates': [{'x': 0.5151, 'y': 0.6649}, {'x': 0.9173, 'y': 0.6649}, {'x': 0.9173, 'y': 0.8925}, {'x': 0.5151, 'y': 0.8925}], 'id': 33, 'page': 2}
# {'category': 'paragraph', 'content': {'html': "<br><p id='34' data-category='paragraph' style='font-size:14px'>Values are represented as number (%), median (1Q, 3Q), or mean<br>土 SD.</p>", 'markdown': 'Values are represented as number (%), median (1Q, 3Q), or mean\n土 SD.', 'text': 'Values are represented as number (%), median (1Q, 3Q), or mean\n土 SD.'}, 'coordinates': [{'x': 0.5163, 'y': 0.8973}, {'x': 0.9198, 'y': 0.8973}, {'x': 0.9198, 'y': 0.9224}, {'x': 0.5163, 'y': 0.9224}], 'id': 34, 'page': 2}
# {'category': 'footer', 'content': {'html': "<footer id='35' style='font-size:16px'>274</footer>", 'markdown': '274', 'text': '274'}, 'coordinates': [{'x': 0.0778, 'y': 0.9448}, {'x': 0.114, 'y': 0.9448}, {'x': 0.114, 'y': 0.9595}, {'x': 0.0778, 'y': 0.9595}], 'id': 35, 'page': 2}
# {'category': 'footer', 'content': {'html': "<br><footer id='36' style='font-size:18px'>www.anesth-pain-med.org</footer>", 'markdown': 'www.anesth-pain-med.org', 'text': 'www.anesth-pain-med.org'}, 'coordinates': [{'x': 0.7545, 'y': 0.9461}, {'x': 0.9223, 'y': 0.9461}, {'x': 0.9223, 'y': 0.9587}, {'x': 0.7545, 'y': 0.9587}], 'id': 36, 'page': 2}
# {'category': 'header', 'content': {'html': "<header id='37' style='font-size:16px'>PICC during anesthesia in MMD children</header>", 'markdown': 'PICC during anesthesia in MMD children', 'text': 'PICC during anesthesia in MMD children'}, 'coordinates': [{'x': 0.3712, 'y': 0.0471}, {'x': 0.627, 'y': 0.0471}, {'x': 0.627, 'y': 0.0609}, {'x': 0.3712, 'y': 0.0609}], 'id': 37, 'page': 3}
# {'category': 'paragraph', 'content': {'html': "<p id='38' data-category='paragraph' style='font-size:14px'>the patient's head was turned to the ipsilateral side. The arm<br>was then moved cephalad in an effort to facilitate successful<br>insertion [9]. The function of the PICC was tested by aspira-<br>tion of blood and flushing with normal saline through the<br>catheter.</p>", 'markdown': "the patient's head was turned to the ipsilateral side. The arm\nwas then moved cephalad in an effort to facilitate successful\ninsertion [9]. The function of the PICC was tested by aspira-\ntion of blood and flushing with normal saline through the\ncatheter.", 'text': "the patient's head was turned to the ipsilateral side. The arm\nwas then moved cephalad in an effort to facilitate successful\ninsertion [9]. The function of the PICC was tested by aspira-\ntion of blood and flushing with normal saline through the\ncatheter."}, 'coordinates': [{'x': 0.077, 'y': 0.0879}, {'x': 0.484, 'y': 0.0879}, {'x': 0.484, 'y': 0.1735}, {'x': 0.077, 'y': 0.1735}], 'id': 38, 'page': 3}
# {'category': 'paragraph', 'content': {'html': "<p id='39' data-category='paragraph' style='font-size:20px'>Confirmation of the catheter tip</p>", 'markdown': 'Confirmation of the catheter tip', 'text': 'Confirmation of the catheter tip'}, 'coordinates': [{'x': 0.0785, 'y': 0.1945}, {'x': 0.3432, 'y': 0.1945}, {'x': 0.3432, 'y': 0.213}, {'x': 0.0785, 'y': 0.213}], 'id': 39, 'page': 3}
# {'category': 'paragraph', 'content': {'html': "<p id='40' data-category='paragraph' style='font-size:14px'>Immediately after insertion of the catheter, the right inter-<br>nal jugular vein was traced using ultrasound to confirm that<br>the catheter did not enter the right internal jugular vein.<br>When the catheter was observed in the right internal jugular<br>vein, the catheter was withdrawn slightly and then reinsert-<br>ed until the catheter was completely inserted but not visible<br>in the right internal jugular vein. If possible, the right subcla-<br>vian vein was also visualized to ensure that the catheter had<br>not migrated into the right innominate vein.</p>", 'markdown': 'Immediately after insertion of the catheter, the right inter-\nnal jugular vein was traced using ultrasound to confirm that\nthe catheter did not enter the right internal jugular vein.\nWhen the catheter was observed in the right internal jugular\nvein, the catheter was withdrawn slightly and then reinsert-\ned until the catheter was completely inserted but not visible\nin the right internal jugular vein. If possible, the right subcla-\nvian vein was also visualized to ensure that the catheter had\nnot migrated into the right innominate vein.', 'text': 'Immediately after insertion of the catheter, the right inter-\nnal jugular vein was traced using ultrasound to confirm that\nthe catheter did not enter the right internal jugular vein.\nWhen the catheter was observed in the right internal jugular\nvein, the catheter was withdrawn slightly and then reinsert-\ned until the catheter was completely inserted but not visible\nin the right internal jugular vein. If possible, the right subcla-\nvian vein was also visualized to ensure that the catheter had\nnot migrated into the right innominate vein.'}, 'coordinates': [{'x': 0.0775, 'y': 0.231}, {'x': 0.4839, 'y': 0.231}, {'x': 0.4839, 'y': 0.3881}, {'x': 0.0775, 'y': 0.3881}], 'id': 40, 'page': 3}
# {'category': 'paragraph', 'content': {'html': '<br><p id=\'41\' data-category=\'paragraph\' style=\'font-size:14px\'>After the end of the surgery, the position of the tip of the<br>catheter was checked via chest radiography (CXR) at the in-<br>tensive care unit or the post-anesthesia care unit. The tip<br>position was classified into three categories: "Optimal" for<br>those located within a 3-cm margin from the cavo-atrial<br>junction, "suboptimal" if they were within the superior vena<br>cava (SVC) or the right atrium, but located outside the 3-cm<br>margin from the cavo-atrial junction, or "malpositioned" in<br>cases involving vessels at locations other than the SVC [10].<br>We defined success as the optimal or suboptimal position of<br>the catheter tip in the postoperative CXR.</p>', 'markdown': 'After the end of the surgery, the position of the tip of the\ncatheter was checked via chest radiography (CXR) at the in-\ntensive care unit or the post-anesthesia care unit. The tip\nposition was classified into three categories: "Optimal" for\nthose located within a 3-cm margin from the cavo-atrial\njunction, "suboptimal" if they were within the superior vena\ncava (SVC) or the right atrium, but located outside the 3-cm\nmargin from the cavo-atrial junction, or "malpositioned" in\ncases involving vessels at locations other than the SVC [10].\nWe defined success as the optimal or suboptimal position of\nthe catheter tip in the postoperative CXR.', 'text': 'After the end of the surgery, the position of the tip of the\ncatheter was checked via chest radiography (CXR) at the in-\ntensive care unit or the post-anesthesia care unit. The tip\nposition was classified into three categories: "Optimal" for\nthose located within a 3-cm margin from the cavo-atrial\njunction, "suboptimal" if they were within the superior vena\ncava (SVC) or the right atrium, but located outside the 3-cm\nmargin from the cavo-atrial junction, or "malpositioned" in\ncases involving vessels at locations other than the SVC [10].\nWe defined success as the optimal or suboptimal position of\nthe catheter tip in the postoperative CXR.'}, 'coordinates': [{'x': 0.077, 'y': 0.3931}, {'x': 0.4842, 'y': 0.3931}, {'x': 0.4842, 'y': 0.5857}, {'x': 0.077, 'y': 0.5857}], 'id': 41, 'page': 3}
# {'category': 'heading1', 'content': {'html': "<h1 id='42' style='font-size:20px'>Statistical analysis</h1>", 'markdown': '# Statistical analysis', 'text': 'Statistical analysis'}, 'coordinates': [{'x': 0.0787, 'y': 0.6054}, {'x': 0.2265, 'y': 0.6054}, {'x': 0.2265, 'y': 0.623}, {'x': 0.0787, 'y': 0.623}], 'id': 42, 'page': 3}
# {'category': 'paragraph', 'content': {'html': "<p id='43' data-category='paragraph' style='font-size:16px'>Demographic data, history of previous surgery, vein se-<br>lected for puncture, depth from skin and diameter of the<br>selected vein, determined insertion length of the catheter,<br>the success rate at the first attempt, overall success rate,<br>number of insertion attempts, reasons for failed attempts,<br>postoperative repositioning of the catheter, duration of<br>postoperative catheter indwelling, and functioning of the<br>catheter were reviewed. Immediate and long-term compli-<br>cations, including hematoma formation, thrombosis, in-<br>fection, insertion site oozing, skin reactions, and catheter<br>migration, were also reviewed. The Pearson correlation CO-<br>efficient between the patient height and the determined<br>insertion length of the catheter was calculated. Statistical<br>analyses were performed using SPSS� statistics version<br>23.0 (IBM, USA).</p>", 'markdown': 'Demographic data, history of previous surgery, vein se-\nlected for puncture, depth from skin and diameter of the\nselected vein, determined insertion length of the catheter,\nthe success rate at the first attempt, overall success rate,\nnumber of insertion attempts, reasons for failed attempts,\npostoperative repositioning of the catheter, duration of\npostoperative catheter indwelling, and functioning of the\ncatheter were reviewed. Immediate and long-term compli-\ncations, including hematoma formation, thrombosis, in-\nfection, insertion site oozing, skin reactions, and catheter\nmigration, were also reviewed. The Pearson correlation CO-\nefficient between the patient height and the determined\ninsertion length of the catheter was calculated. Statistical\nanalyses were performed using SPSS� statistics version\n23.0 (IBM, USA).', 'text': 'Demographic data, history of previous surgery, vein se-\nlected for puncture, depth from skin and diameter of the\nselected vein, determined insertion length of the catheter,\nthe success rate at the first attempt, overall success rate,\nnumber of insertion attempts, reasons for failed attempts,\npostoperative repositioning of the catheter, duration of\npostoperative catheter indwelling, and functioning of the\ncatheter were reviewed. Immediate and long-term compli-\ncations, including hematoma formation, thrombosis, in-\nfection, insertion site oozing, skin reactions, and catheter\nmigration, were also reviewed. The Pearson correlation CO-\nefficient between the patient height and the determined\ninsertion length of the catheter was calculated. Statistical\nanalyses were performed using SPSS� statistics version\n23.0 (IBM, USA).'}, 'coordinates': [{'x': 0.0769, 'y': 0.6411}, {'x': 0.4837, 'y': 0.6411}, {'x': 0.4837, 'y': 0.9067}, {'x': 0.0769, 'y': 0.9067}], 'id': 43, 'page': 3}
# {'category': 'paragraph', 'content': {'html': "<br><p id='44' data-category='paragraph' style='font-size:20px'>Outcomes of PICC insertion</p>", 'markdown': 'Outcomes of PICC insertion', 'text': 'Outcomes of PICC insertion'}, 'coordinates': [{'x': 0.5162, 'y': 0.0879}, {'x': 0.7457, 'y': 0.0879}, {'x': 0.7457, 'y': 0.1051}, {'x': 0.5162, 'y': 0.1051}], 'id': 44, 'page': 3}
# {'category': 'paragraph', 'content': {'html': "<p id='45' data-category='paragraph' style='font-size:14px'>Among the 30 patients, the procedure was completed in<br>27 (90.0%) patients, while we failed to introduce the catheter<br>in the other 3 patients. Twenty-two (73.3%) cases showed<br>successful PICC with optimal or suboptimal positioning of<br>the catheter tip on confirmation with CXR. Insertion was<br>successful in the first attempt in 19 patients. Detailed infor-<br>mation on the insertion attempts is presented in Table 2.</p>", 'markdown': 'Among the 30 patients, the procedure was completed in\n27 (90.0%) patients, while we failed to introduce the catheter\nin the other 3 patients. Twenty-two (73.3%) cases showed\nsuccessful PICC with optimal or suboptimal positioning of\nthe catheter tip on confirmation with CXR. Insertion was\nsuccessful in the first attempt in 19 patients. Detailed infor-\nmation on the insertion attempts is presented in Table 2.', 'text': 'Among the 30 patients, the procedure was completed in\n27 (90.0%) patients, while we failed to introduce the catheter\nin the other 3 patients. Twenty-two (73.3%) cases showed\nsuccessful PICC with optimal or suboptimal positioning of\nthe catheter tip on confirmation with CXR. Insertion was\nsuccessful in the first attempt in 19 patients. Detailed infor-\nmation on the insertion attempts is presented in Table 2.'}, 'coordinates': [{'x': 0.516, 'y': 0.1238}, {'x': 0.922, 'y': 0.1238}, {'x': 0.922, 'y': 0.2455}, {'x': 0.516, 'y': 0.2455}], 'id': 45, 'page': 3}
# ...
# {'category': 'paragraph', 'content': {'html': "<p id='79' data-category='paragraph' style='font-size:16px'>The datasets generated during and/or analyzed during the<br>current study are available from the corresponding author<br>on reasonable request.</p>", 'markdown': 'The datasets generated during and/or analyzed during the\ncurrent study are available from the corresponding author\non reasonable request.', 'text': 'The datasets generated during and/or analyzed during the\ncurrent study are available from the corresponding author\non reasonable request.'}, 'coordinates': [{'x': 0.5182, 'y': 0.6594}, {'x': 0.921, 'y': 0.6594}, {'x': 0.921, 'y': 0.7105}, {'x': 0.5182, 'y': 0.7105}], 'id': 79, 'page': 5}
# {'category': 'paragraph', 'content': {'html': "<p id='80' data-category='paragraph' style='font-size:20px'>AUTHOR CONTRIBUTIONS</p>", 'markdown': 'AUTHOR CONTRIBUTIONS', 'text': 'AUTHOR CONTRIBUTIONS'}, 'coordinates': [{'x': 0.6041, 'y': 0.7306}, {'x': 0.8362, 'y': 0.7306}, {'x': 0.8362, 'y': 0.7477}, {'x': 0.6041, 'y': 0.7477}], 'id': 80, 'page': 5}
# {'category': 'paragraph', 'content': {'html': "<p id='81' data-category='paragraph' style='font-size:16px'>Conceptualization: Hee-Soo Kim. Data curation: Sang-<br>Hwan Ji, Sol Ji Yoo, Hee-Soo Kim. Formal analysis: Sol Ji Yoo,<br>Eun-Hee Kim, Ji-Hyun Lee. Methodology: Young-Eun Jang,<br>Jin-Tae Kim. Investigation: Sang-Hwan Ji, Sung-Ae Cho, Eun-<br>Hee Kim, Hee-Soo Kim. Software: Sung-Ae Cho, Young-Eun<br>Jang, Eun-Hee Kim. Writing - original draft: Sang-Hwan Ji,<br>Sol Ji Yoo, Sung-Ae Cho, Hee-Soo Kim. Writing - review &<br>editing: Sang-Hwan Ji, Young-Eun Jang, Eun-Hee Kim, Ji-<br>Hyun Lee, Jin-Tae Kim, Hee-Soo Kim.</p>", 'markdown': 'Conceptualization: Hee-Soo Kim. Data curation: Sang-\nHwan Ji, Sol Ji Yoo, Hee-Soo Kim. Formal analysis: Sol Ji Yoo,\nEun-Hee Kim, Ji-Hyun Lee. Methodology: Young
; 71:\n- 378-80.\n- 10. Kwon S, Son SM, Lee SH, Kim JH, Kim H, Kim JY, et al. Out-\n- comes of bedside peripherally inserted central catheter place-\n- ment: a retrospective study at a single institution. Acute Crit\n- Care 2020; 35:31-7.\n- 11. Kim YO, Chung CR, Gil E, Park CM, Suh GY, Ryu JA. Safety and\n- feasibility of ultrasound-guided placement of peripherally in-\n- serted central catheter performed by neurointensivist in neu-\n- rosurgery intensive care unit. PLoS One 2019; 14: e0217641.\n- 12. Jumani K, Advani S, Reich NG, Gosey L, Milstone AM. Risk fac-\n- tors for peripherally inserted central venous catheter compli-\n- cations in children. JAMA Pediatr 2013; 167: 429-35.\n- 13. Glauser F, Breault S, Rigamonti F, Sotiriadis C, Jouannic AM,\n- Qanadli SD. Tip malposition of peripherally inserted central\n- catheters: a prospective randomized controlled trial to com-\n- pare bedside insertion to fluoroscopically guided placement.\n- Eur Radiol 2017;27: 2843-9.\n- 14. Connolly B, Amaral J, Walsh S, Temple M, Chait P, Stephens D.\n- Influence of arm movement on central tip location of periph-\n- erally inserted central catheters (PICCs). Pediatr Radiol 2006;\n- 36: 845-50.\n- 15. Grau D, Clarivet B, Lotthe A, Bommart S, Parer S. Complica-\n- tions with peripherally inserted central catheters (PICCs) used\n- in hospitalized patients and outpatients: a prospective cohort\n- study. Antimicrob Resist Infect Control 2017; 6: 18.\n- 16. Ramamurthi A, Chick JFB, Srinivasa RN, Hage AN, Grove JJ,\n- Gemmete JJ, et al. Chest radiograph measurement technique\n- facilitates accurate bedside peripherally inserted central cath-\n- eter placement in children. Cardiovasc Intervent Radiol 2018;\n- 41: 443-8.\n', 'text': '9. Ragasa J, Shah N, Watson RC. Where antecubital catheters go:\na study under fluoroscopic control. Anesthesiology 1989; 71:\n378-80.\n10. Kwon S, Son SM, Lee SH, K ...
# {'category': 'footer', 'content': {'html': "<footer id='92' style='font-size:16px'>278</footer>", 'markdown': '278', 'text': '278'}, 'coordinates': [{'x': 0.0779, 'y': 0.9448}, {'x': 0.1162, 'y': 0.9448}, {'x': 0.1162, 'y': 0.9596}, {'x': 0.0779, 'y': 0.9596}], 'id': 92, 'page': 6}
# {'category': 'footer', 'content': {'html': "<br><footer id='93' style='font-size:18px'>www.anesth-pain-med.org</footer>", 'markdown': 'www.anesth-pain-med.org', 'text': 'www.anesth-pain-med.org'}, 'coordinates': [{'x': 0.7537, 'y': 0.9456}, {'x': 0.9229, 'y': 0.9456}, {'x': 0.9229, 'y': 0.9593}, {'x': 0.7537, 'y': 0.9593}], 'id': 93, 'page': 6}

# %%
from langchain_core.documents import Document

documents = []
export_categories = {'heading1', 'paragraph', 'list'}
except_text = ['기본 기능','설정', '애플리케이션', '부록']

for element in data_list:

    text_content = element['content']['text'].strip()
    if text_content in except_text:
        continue

    category = element['category']

    if category != 'table' and category not in export_categories:
         continue

     # 기본 메타데이터 구성
    metadata = {
        'type': category,
        'page': element['page'],
        'text': element['content']['text']
        }
    

    documents.append(
        Document(page_content=element['content']['markdown'], metadata=metadata))

# %%
documents
# Out:
# [Document(metadata={'type': 'heading1', 'page': 1, 'text': 'apm\nANESTHESIA & PAIN MEDICINE'}, page_content='# apm\nANESTHESIA & PAIN MEDICINE'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'Check for\nupdates'}, page_content='Check for\nupdates'),
#  Document(metadata={'type': 'heading1', 'page': 1, 'text': 'Case Report'}, page_content='# Case Report'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'Anesth Pain Med 2021;16:273-278\nhttps://doi.org/10.17085/apm.20099\npISSN 1975-5171 · eISSN 2383-7977'}, page_content='Anesth Pain Med 2021;16:273-278\nhttps://doi.org/10.17085/apm.20099\npISSN 1975-5171 · eISSN 2383-7977'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'Received December 28, 2020\nRevised March 10, 2021\nAccepted March 14, 2021'}, page_content='Received December 28, 2020\nRevised March 10, 2021\nAccepted March 14, 2021'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'Corresponding author'}, page_content='Corresponding author'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'Hee-Soo Kim, M.D., Ph.D.\nDepartment of Anesthesiology and\nPain Medicine, Seoul National\nUniversity Hospital, 101 Daehak-ro,\nJongno-gu, Seoul 03080, Korea\nTel: 82-2-2072-3659\nFax: 82-2-745-5587\nE-mail: dami0605@snu.ac.kr'}, page_content='Hee-Soo Kim, M.D., Ph.D.\nDepartment of Anesthesiology and\nPain Medicine, Seoul National\nUniversity Hospital, 101 Daehak-ro,\nJongno-gu, Seoul 03080, Korea\nTel: 82-2-2072-3659\nFax: 82-2-745-5587\nE-mail: dami0605@snu.ac.kr'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'This study was presented in the\nKorean Society of Pediatric Anesthesia\nAnnual Meeting, 17 October 2020,\nonline.'}, page_content='This study was presented in the\nKorean Society of Pediatric Anesthesia\nAnnual Meeting, 17 October 2020,\nonline.'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'Central venous catheterization is frequently performed\nduring general anesthesia, mainly for fluid administration\nand monitoring of central venous pressure. In addition, the\nneed for frequent blood sampling can also be a reason for\ncentral venous catheterization to reduce the pain or fear of\nneedle insertion. Since pediatric patients with moyamoya\ndisease (MMD) are at risk ofischemic attack when crying or\nundergoing physical or emotional stress, a central venous'}, page_content='Central venous catheterization is frequently performed\nduring general anesthesia, mainly for fluid administration\nand monitoring of central venous pressure. In addition, the\nneed for frequent blood sampling can also be a reason for\ncentral venous catheterization to reduce the pain or fear of\nneedle insertion. Since pediatric patients with moyamoya\ndisease (MMD) are at risk ofischemic attack when crying or\nundergoing physical or emotional stress, a central venous'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'Ultrasound-guided insertion of peripherally\ninserted central catheter after anesthetic\ninduction in children undergoing surgery for\nmoyamoya disease\n- Thirty cases report -'}, page_content='Ultrasound-guided insertion of peripherally\ninserted central catheter after anesthetic\ninduction in children undergoing surgery for\nmoyamoya disease\n- Thirty cases report -'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': "Sang-Hwan Ji', Sol Ji Yoo' Sung-Ae Cho2, Young-Eun Jang1\nEun-Hee Kim1 Ji-Hyun Lee1 Jin-Tae Kim . and Hee-Soo Kim 1,3\n,"}, page_content="Sang-Hwan Ji', Sol Ji Yoo' Sung-Ae Cho2, Young-Eun Jang1\nEun-Hee Kim1 Ji-Hyun Lee1 Jin-Tae Kim . and Hee-Soo Kim 1,3\n,"),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': "'Department of Anesthesiology and Pain Medicine, Seoul National University Hospital,\nSeoul, 2Department of Anesthesiology and Pain Medicine, Konyang University Hospital,\nDaejeon, 3Department of Anesthesiology and Pain Medicine, Seoul National University\nCollege of Medicine, Seoul, Korea"}, page_content="'Department of Anesthesiology and Pain Medicine, Seoul National University Hospital,\nSeoul, 2Department of Anesthesiology and Pain Medicine, Konyang University Hospital,\nDaejeon, 3Department of Anesthesiology and Pain Medicine, Seoul National University\nCollege of Medicine, Seoul, Korea"),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'Background: Pediatric patients with moyamoya disease are vulnerable to ischemic attacks\nfollowing physical or emotional stress, such as those experienced during blood sampling. A\ncentral venous catheter might be beneficial for blood sampling, and a peripherally inserted\ncentral catheter (PICC) is a considerable option for central venous access. However, PICC in-\nsertion during anesthetic management is relatively rare.'}, page_content='Background: Pediatric patients with moyamoya disease are vulnerable to ischemic attacks\nfollowing physical or emotional stress, such as those experienced during blood sampling. A\ncentral venous catheter might be beneficial for blood sampling, and a peripherally inserted\ncentral catheter (PICC) is a considerable option for central venous access. However, PICC in-\nsertion during anesthetic management is relatively rare.'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'Case: Thirty cases of ultrasound-guided PICC insertion were performed in children undergo-\ning surgery for moyamoya disease after anesthetic induction. Positioning was successful in\n22 cases, and 5 were malpositioned. In three cases, the peripheral insertion failed. Adjust-\nment of the insertion depth was performed in nine cases. No complications related to cath-\neterization were observed during the procedure or the catheter indwelling period.'}, page_content='Case: Thirty cases of ultrasound-guided PICC insertion were performed in children undergo-\ning surgery for moyamoya disease after anesthetic induction. Positioning was successful in\n22 cases, and 5 were malpositioned. In three cases, the peripheral insertion failed. Adjust-\nment of the insertion depth was performed in nine cases. No complications related to cath-\neterization were observed during the procedure or the catheter indwelling period.'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'Conclusions: We report the successful use of PICC in children undergoing surgery for moy-\namoya disease with a considerable success rate and low incidence of malpositioning or\ncomplications.'}, page_content='Conclusions: We report the successful use of PICC in children undergoing surgery for moy-\namoya disease with a considerable success rate and low incidence of malpositioning or\ncomplications.'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'Keywords: Children; General anesthesia; Central venous catheterization; Moyamoya dis-\nease; Neurosurgery; Ultrasonography.'}, page_content='Keywords: Children; General anesthesia; Central venous catheterization; Moyamoya dis-\nease; Neurosurgery; Ultrasonography.'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'catheter would be helpful for postoperative blood sampling\nor fluid management to prevent these events.'}, page_content='catheter would be helpful for postoperative blood sampling\nor fluid management to prevent these events.'),
#  Document(metadata={'type': 'paragraph', 'page': 1, 'text': 'A peripherally inserted central catheter (PICC) is a good\noption for central venous access [1] with good compliance,\nlow complication rate [2,3], and readiness for ambulation af-\nter surgery, compared to the internal jugular or subclavian\nveins. However, it is rarely selected by anesthesiologists in\nthe operating room. While PICC can be inserted at the bed-'}, page_content='A peripherally inserted central catheter (PICC) is a good\noption for central venous access [1] with good compliance,\nlow complication rate [2,3], and readiness for ambulation af-\nter surgery, compared to the internal jugular or subclavian\nveins. However, it is rarely selected by anesthesiologists in\nthe operating room. While PICC can be inserted at the bed-'),
#  Document(metadata={'type': 'paragraph', 'page': 2, 'text': 'side or under fluoroscopic guidance prior to surgery for\nadults, PICC insertion for pediatric patients is not easy, and\nthey require sedation for the procedure in most cases. Under\ngeneral anesthesia, ultrasound is readily applicable to pedi-\natric patients without causing radiation hazards compared\nto fluoroscopy, which is frequently used as a guide for PICC\ninsertion.'}, page_content='side or under fluoroscopic guidance prior to surgery for\nadults, PICC insertion for pediatric patients is not easy, and\nthey require sedation for the procedure in most cases. Under\ngeneral anesthesia, ultrasound is readily applicable to pedi-\natric patients without causing radiation hazards compared\nto fluoroscopy, which is frequently used as a guide for PICC\ninsertion.'),
#  Document(metadata={'type': 'paragraph', 'page': 2, 'text': 'We recently introduced a policy to insert the PICC under\nultrasound guidance after induction of general anesthesia in\npediatric patients undergoing surgery for MMD. We report\nour cases along with a summary of the success and compli-\ncation rates.'}, page_content='We recently introduced a policy to insert the PICC under\nultrasound guidance after induction of general anesthesia in\npediatric patients undergoing surgery for MMD. We report\nour cases along with a summary of the success and compli-\ncation rates.'),
#  Document(metadata={'type': 'heading1', 'page': 2, 'text': 'CASE REPORT'}, page_content='# CASE REPORT'),
#  Document(metadata={'type': 'heading1', 'page': 2, 'text': 'Ethics statement'}, page_content='# Ethics statement'),
#  Document(metadata={'type': 'paragraph', 'page': 2, 'text': "This report was approved by the Institutional Review\nBoard of Seoul National University Hospital (no. 2004-231-\n1119), and the requirement for obtaining informed consent\nwas waived. The reason for the exemption from consent was\nas follows: First, obtaining informed consent from the pa-\ntients was not feasible because they had already been dis-\ncharged from the hospital at the moment we started to re-\nview the cases. Second, there was no reason to assume dis-\nagreement regarding the use of data from the patients, and\nthere was no chance of affecting any of the patients' treat-\nment or prognosis."}, page_content="This report was approved by the Institutional Review\nBoard of Seoul National University Hospital (no. 2004-231-\n1119), and the requirement for obtaining informed consent\nwas waived. The reason for the exemption from consent was\nas follows: First, obtaining informed consent from the pa-\ntients was not feasible because they had already been dis-\ncharged from the hospital at the moment we started to re-\nview the cases. Second, there was no reason to assume dis-\nagreement regarding the use of data from the patients, and\nthere was no chance of affecting any of the patients' treat-\nment or prognosis."),
#  Document(metadata={'type': 'heading1', 'page': 2, 'text': 'Study population'}, page_content='# Study population'),
) to select the venipuncture site. If the basilic vein was\nselected, the elbow was flexed at 90°, while it was extended\nto the cephalic vein. The patient's right arm was covered\nwith a surgical drape after sterilization. Turbo-Ject� pow-\ner-injectable PICC (Cook Medical LLC, USA) with a size of3\nor 4 Fr was prepared. Even though 4-Fr catheters are recom-\nmended for veins larger than 4 mm in diameter [5], a larger\ncatheter size may be related to a higher risk of thrombosis\n[6]. In most cases, we used 3-Fr catheters in an effort to use a\ncatheter as small as possible to prevent thrombosis. Cathe-\nters sized 4 Fr were used only for patients weighing > 70 kg.\nBefore venipuncture, the length of catheter insertion was\ndetermined by measuring the distance between the targeted\nvenipuncture site and the sternal notch [7]. The catheter was\nthen trimmed according to the required length. The targeted\nvein was punctured under ultrasound guidance, followed by\nthe insertion of a 20-gauge intravenous BD angiocath TM\n(Becton, Dickinson, and company Korea, Korea) catheter. To\nensure stability, we tried to maintain a distance of at least 4\ncm between the antecubital fossa and venipuncture site [8].\nSubsequently, a guidewire was inserted via an intravenous\ncatheter. An introducer was inserted along the guidewire af-\nter a minimal skin incision was made at the venipuncture\nsite. After removal of the guidewire, the PICC was inserted\nthrough the introducer and advanced until the entire cathe-\nter was inserted. During the advancement of the catheter,"),
#  Document(metadata={'type': 'paragraph', 'page': 2, 'text': 'Table 1. Baseline Characteristics of Subjects, Selected Veins, and\nCatheter Size for Insertion of a Peripherally-inserted Central Catheter'}, page_content='Table 1. Baseline Characteristics of Subjects, Selected Veins, and\nCatheter Size for Insertion of a Peripherally-inserted Central Catheter'),
#  Document(metadata={'type': 'table', 'page': 2, 'text': 'Characteristic Value\n Sex (M/F) 20/10\n Age (yr) 7.5 (6, 9)\n Height (cm) 124.0 (115.7, 146.2)\n Weight (kg) 28.4 (21.7, 46.6)\n Selected vein \n Basilic 21 (70.0)\n Cephalic 6 (20.0)\n Failure for both 3 (10.0)\n Vein diameter (mm) 4.0 土 0.9\n Vein depth (mm) 5.4 (4.1, 8.5)\n Catheter size (Fr) \n 3 26 (86.7)\n 4 4 (13.3)'}, page_content='| Characteristic | Value |\n| --- | --- |\n| Sex (M/F) | 20/10 |\n| Age (yr) | 7.5 (6, 9) |\n| Height (cm) | 124.0 (115.7, 146.2) |\n| Weight (kg) | 28.4 (21.7, 46.6) |\n| Selected vein |  |\n| Basilic | 21 (70.0) |\n| Cephalic | 6 (20.0) |\n| Failure for both | 3 (10.0) |\n| Vein diameter (mm) | 4.0 土 0.9 |\n| Vein depth (mm) | 5.4 (4.1, 8.5) |\n| Catheter size (Fr) |  |\n| 3 | 26 (86.7) |\n| 4 | 4 (13.3) |\n'),
#  Document(metadata={'type': 'paragraph', 'page': 2, 'text': 'Values are represented as number (%), median (1Q, 3Q), or mean\n土 SD.'}, page_content='Values are represented as number (%), median (1Q, 3Q), or mean\n土 SD.'),
#  Document(metadata={'type': 'paragraph', 'page': 3, 'text': "the patient's head was turned to the ipsilateral side. The arm\nwas then moved cephalad in an effort to facilitate successful\ninsertion [9]. The function of the PICC was tested by aspira-\ntion of blood and flushing with normal saline through the\ncatheter."}, page_content="the patient's head was turned to the ipsilateral side. The arm\nwas then moved cephalad in an effort to facilitate successful\ninsertion [9]. The function of the PICC was tested by aspira-\ntion of blood and flushing with normal saline through the\ncatheter."),
#  Document(metadata={'type': 'paragraph', 'page': 3, 'text': 'Confirmation of the catheter tip'}, page_content='Confirmation of the catheter tip'),
#  Document(metadata={'type': 'paragraph', 'page': 3, 'text': 'Immediately after insertion of the catheter, the right inter-\nnal jugular vein was traced using ultrasound to confirm that\nthe catheter did not enter the right internal jugular vein.\nWhen the catheter was observed in the right internal jugular\nvein, the catheter was withdrawn slightly and then reinsert-\ned until the catheter was completely inserted but not visible\nin the right internal jugular vein. If possible, the right subcla-\nvian vein was also visualized to ensure that the catheter had\nnot migrated into the right innominate vein.'}, page_content='Immediately after insertion of the catheter, the right inter-\nnal jugular vein was traced using ultrasound to confirm that\nthe catheter did not enter the right internal jugular vein.\nWhen the catheter was observed in the right internal jugular\nvein, the catheter was withdrawn slightly and then reinsert-\ned until the catheter was completely inserted but not visible\nin the right internal jugular vein. If possible, the right subcla-\nvian vein was also visualized to ensure that the catheter had\nnot migrated into the right innominate vein.'),
#  Document(metadata={'type': 'paragraph', 'page': 3, 'text': 'After the end of the surgery, the position of the tip of the\ncatheter was checked via chest radiography (CXR) at the in-\ntensive care unit or the post-anesthesia care unit. The tip\nposition was classified into three categories: "Optimal" for\nthose located within a 3-cm margin from the cavo-atrial\njunction, "suboptimal" if they were within the superior vena\ncava (SVC) or the right atrium, but located outside the 3-cm\nmargin from the cavo-atrial junction, or "malpositioned" in\ncases involving vessels at locations other than the SVC [10].\nWe defined success as the optimal or suboptimal position of\nthe catheter tip in the postoperative CXR.'}, page_content='After the end of the surgery, the position of the tip of the\ncatheter was checked via chest radiography (CXR) at the in-\ntensive care unit or the post-anesthesia care unit. The tip\nposition was classified into three categories: "Optimal" for\nthose located within a 3-cm margin from the cavo-atrial\njunction, "suboptimal" if they were within the superior vena\ncava (SVC) or the right atrium, but located outside the 3-cm\nmargin from the cavo-atrial junction, or "malpositioned" in\ncases involving vessels at locations other than the SVC [10].\nWe defined success as the optimal or suboptimal position of\nthe catheter tip in the postoperative CXR.'),
#  Document(metadata={'type': 'heading1', 'page': 3, 'text': 'Statistical analysis'}, page_content='# Statistical analysis'),
#  Document(metadata={'type': 'paragraph', 'page': 3, 'text': 'Demographic data, history of previous surgery, vein se-\nlected for puncture, depth from skin and diameter of the\nselected vein, determined insertion length of the catheter,\nthe success rate at the first attempt, overall success rate,\nnumber of insertion attempts, reasons for failed attempts,\npostoperative repositioning of the catheter, duration of\npostoperative catheter indwelling, and functioning of the\ncatheter were reviewed. Immediate and long-term compli-\ncations, including hematoma formation, thrombosis, in-\nfection, insertion site oozing, skin reactions, and catheter\nmigration, were also reviewed. The Pearson correlation CO-\nefficient between the patient height and the determined\ninsertion length of the catheter was calculated. Statistical\nanalyses were performed using SPSS� statistics version\n23.0 (IBM, USA).'}, page_content='Demographic data, history of previous surgery, vein se-\nlected for puncture, depth from skin and diameter of the\nselected vein, determined insertion length of the catheter,\nthe success rate at the first attempt, overall success rate,\nnumber of insertion attempts, reasons for failed attempts,\npostoperative repositioning of the catheter, duration of\npostoperative catheter indwelling, and functioning of the\ncatheter were reviewed. Immediate and long-term compli-\ncations, including hematoma formation, thrombosis, in-\nfection, insertion site oozing, skin reactions, and catheter\nmigration, were also reviewed. The Pearson correlation CO-\nefficient between the patient height and the determined\ninsertion length of the catheter was calculated. Statistical\nanalyses were performed using SPSS� statistics version\n23.0 (IBM, USA).'),
#  Document(metadata={'type': 'paragraph', 'page': 3, 'text': 'Outcomes of PICC insertion'}, page_content='Outcomes of PICC insertion'),
#  Document(metadata={'type': 'paragraph', 'page': 3, 'text': 'Among the 30 patients, the procedure was completed in\n27 (90.0%) patients, while we failed to introduce the catheter\nin the other 3 patients. Twenty-two (73.3%) cases showed\nsuccessful PICC with optimal or suboptimal positioning of\nthe catheter tip on confirmation with CXR. Insertion was\nsuccessful in the first attempt in 19 patients. Detailed infor-\nmation on the insertion attempts is presented in Table 2.'}, page_content='Among the 30 patients, the procedure was completed in\n27 (90.0%) patients, while we failed to introduce the catheter\nin the other 3 patients. Twenty-two (73.3%) cases showed\nsuccessful PICC with optimal or suboptimal positioning of\nthe catheter tip on confirmation with CXR. Insertion was\nsuccessful in the first attempt in 19 patients. Detailed infor-\nmation on the insertion attempts is presented in Table 2.'),
#  Document(metadata={'type': 'paragraph', 'page': 3, 'text': 'Upon confirmation with postoperative CXRs for the com-\npleted cases, 5 (16.7%) cases showed malpositioning of the\ncatheter, 3 in the right internal jugular vein, and 2 in the left\nbrachiocephalic vein. Fig. 1 shows examples of CXRs for the\nsuccessful placement and malpositioning of the catheter tip.\nAmong the malpositioned cases, the basilic vein was select-\ned in four cases and the cephalic vein was selected in one\ncase. In one case of malpositioning of the internal jugular\nvein, the PICC was revised in the angiography room the day\nafter. In another case of malpositioning of the internal jugu-\nlar vein, the catheter was withdrawn by 4 cm. In the remain-\ning 3 malpositioned cases, the catheter was used without re-\npositioning. In 6 cases, the catheter tip was located deeper\nthan expected. In these cases, the catheter was withdrawn\nby a median (1Q, 3Q) of 3.8 (3.1, 5.5) cm. Two of the with-\ndrawn cases involved follow-up CXRs, which confirmed the\nwithdrawal of the catheter to the proximal end of the right'}, page_content='Upon confirmation with postoperative CXRs for the com-\npleted cases, 5 (16.7%) cases showed malpositioning of the\ncatheter, 3 in the right internal jugular vein, and 2 in the left\nbrachiocephalic vein. Fig. 1 shows examples of CXRs for the\nsuccessful placement and malpositioning of the catheter tip.\nAmong the malpositioned cases, the basilic vein was select-\ned in four cases and the cephalic vein was selected in one\ncase. In one case of malpositioning of the internal jugular\nvein, the PICC was revised in the angiography room the day\nafter. In another case of malpositioning of the internal jugu-\nlar vein, the catheter was withdrawn by 4 cm. In the remain-\ning 3 malpositioned cases, the catheter was used without re-\npositioning. In 6 cases, the catheter tip was located deeper\nthan expected. In these cases, the catheter was withdrawn\nby a median (1Q, 3Q) of 3.8 (3.1, 5.5) cm. Two of the with-\ndrawn cases involved follow-up CXRs, which confirmed the\nwithdrawal of the catheter to the proximal end of the right'),
#  Document(metadata={'type': 'table', 'page': 3, 'text': 'Subject Value\n Catheter insertion length (cm) 28 (26, 32)\n Number of attempts to success \n 1 19 (63.3)\n 2 6 (20.0)\n 3 2 (6.7)\n Reason for failed attempts (n = 17) \n Venipuncture failure 3 (17.6)\n Guidewire insertion failure 2 (11.8)\n Dilation failure 3 (17.6)\n Catheter advancement failure 9 (52.9)\n Catheter tip position \n Optimal* 14 (46.7)\n Suboptimal† 8 (26.7)\n Malpositioning‡ 5 (16.7)\n Failure§ 3 (10.0)'}, page_content='| Subject | Value |\n| --- | --- |\n| Catheter insertion length (cm) | 28 (26, 32) |\n| Number of attempts to success |  |\n| 1 | 19 (63.3) |\n| 2 | 6 (20.0) |\n| 3 | 2 (6.7) |\n| Reason for failed attempts (n = 17) |  |\n| Venipuncture failure | 3 (17.6) |\n| Guidewire insertion failure | 2 (11.8) |\n| Dilation failure | 3 (17.6) |\n| Catheter advancement failure | 9 (52.9) |\n| Catheter tip position |  |\n| Optimal* | 14 (46.7) |\n| Suboptimal† | 8 (26.7) |\n| Malpositioning‡ | 5 (16.7) |\n| Failure§ | 3 (10.0) |\n'),
#  Document(metadata={'type': 'paragraph', 'page': 3, 'text': 'Values are represented as median (1Q, 3Q) or number (%).\n*Located within a 3-cm margin from the cavoatrial junction.\n+Located within the superior vena cava (SVC) or the right atrium\nand could be easily repositioned by the withdrawal of the catheter.\n*Locations other than the SVC. SFailed to insert the catheter.'}, page_content='Values are represented as median (1Q, 3Q) or number (%).\n*Located within a 3-cm margin from the cavoatrial junction.\n+Located within the superior vena cava (SVC) or the right atrium\nand could be easily repositioned by the withdrawal of the catheter.\n*Locations other than the SVC. SFailed to insert the catheter.'),
#  Document(metadata={'type': 'paragraph', 'page': 4, 'text': 'subclavian vein. In one case, the insertion length was short-\ner than expected to an extent of 5 cm, and there was no ad-\njustment.'}, page_content='subclavian vein. In one case, the insertion length was short-\ner than expected to an extent of 5 cm, and there was no ad-\njustment.'),
#  Document(metadata={'type': 'paragraph', 'page': 4, 'text': 'In 3 patients, the catheter was unexpectedly withdrawn\nduring transportation ofthe patient from the operating room\nto the intensive care unit, while re-insertion of the catheter\nwas not performed. All successful cases showed intact cath-\neter function, with no reported immediate complications\nsuch as hematoma, thrombosis, skin irritation, or bleeding.'}, page_content='In 3 patients, the catheter was unexpectedly withdrawn\nduring transportation ofthe patient from the operating room\nto the intensive care unit, while re-insertion of the catheter\nwas not performed. All successful cases showed intact cath-\neter function, with no reported immediate complications\nsuch as hematoma, thrombosis, skin irritation, or bleeding.'),
#  Document(metadata={'type': 'paragraph', 'page': 4, 'text': "The median (1Q, 3Q) duration of indwelling was 7 (6, 8)\ndays, and the total indwelling time for all subjects was 184\nPICC-days with no reported complications or complaints of\ndiscomfort. There was a strong positive correlation between\nthe patient's height and the insertion length of the catheter,\nwith a Pearson correlation coefficient of0.906 (P < 0.001)."}, page_content="The median (1Q, 3Q) duration of indwelling was 7 (6, 8)\ndays, and the total indwelling time for all subjects was 184\nPICC-days with no reported complications or complaints of\ndiscomfort. There was a strong positive correlation between\nthe patient's height and the insertion length of the catheter,\nwith a Pearson correlation coefficient of0.906 (P < 0.001)."),
#  Document(metadata={'type': 'paragraph', 'page': 4, 'text': 'Four patients were included twice in our data, and all\nshowed successful insertion during the first operation. In\nthe second operation, the four cases showed a failure of\nPICC insertion, malpositioning to the contralateral side, suc-\ncessful insertion in the same vein, and successful insertion\nin the alternate vein (cephalic-basilic).'}, page_content='Four patients were included twice in our data, and all\nshowed successful insertion during the first operation. In\nthe second operation, the four cases showed a failure of\nPICC insertion, malpositioning to the contralateral side, suc-\ncessful insertion in the same vein, and successful insertion\nin the alternate vein (cephalic-basilic).'),
#  Document(metadata={'type': 'paragraph', 'page': 4, 'text': "We did not survey patient satisfaction with PICC after sur-\ngery. However, neurosurgeons in charge of their in-hospital\ncare reported an overall increase in patients' comfort and\nstability during the hospital stay with PICC compared to ac-\ncess via the internal jugular or subclavian veins."}, page_content="We did not survey patient satisfaction with PICC after sur-\ngery. However, neurosurgeons in charge of their in-hospital\ncare reported an overall increase in patients' comfort and\nstability during the hospital stay with PICC compared to ac-\ncess via the internal jugular or subclavian veins."),
#  Document(metadata={'type': 'paragraph', 'page': 4, 'text': 'DISCUSSION'}, page_content='DISCUSSION'),
#  Document(metadata={'type': 'paragraph', 'page': 4, 'text': 'We summarized cases of PICC insertion under ultrasound'}, page_content='We summarized cases of PICC insertion under ultrasound'),
#  Document(metadata={'type': 'paragraph', 'page': 4, 'text': 'guidance after induction of general anesthesia in pediatric\npatients undergoing surgery for MMD with successful posi-\ntioning ofthe catheter tip in 22 out of30 cases.'}, page_content='guidance after induction of general anesthesia in pediatric\npatients undergoing surgery for MMD with successful posi-\ntioning ofthe catheter tip in 22 out of30 cases.'),
#  Document(metadata={'type': 'paragraph', 'page': 4, 'text': 'In recent studies, success rates defined as proper position-\ning of the PICC catheter with ultrasound-guided insertion\nhave been reported to be about 81.2% and 94.4% [10,11] in\nadults and 83.9% [12] in children. Our success rate of 73.3%\nwas relatively lower than these results. In our cases, catheter\ninsertion was performed during anesthesia and prior to sur-\ngery. As we just introduced the policy of PICC insertion in\nour department, the proficiency of the practitioner might be\na cause for the lower success rate. Moreover, since we re-\nviewed only a small number of cases, the success rate may be\ninconsistent with previous data. Among the three cases of\nfailed insertion, it was difficult to advance the catheter into\nthe right subclavian vein with or without the obturator in two\ncases, and advancement of the introducer was impossible in\nthe other case. Reports of common reasons for PICC inser-\ntion failure are difficult to find in the literature, so we could\nnot compare our results with those of previous studies.'}, page_content='In recent studies, success rates defined as proper position-\ning of the PICC catheter with ultrasound-guided insertion\nhave been reported to be about 81.2% and 94.4% [10,11] in\nadults and 83.9% [12] in children. Our success rate of 73.3%\nwas relatively lower than these results. In our cases, catheter\ninsertion was performed during anesthesia and prior to sur-\ngery. As we just introduced the policy of PICC insertion in\nour department, the proficiency of the practitioner might be\na cause for the lower success rate. Moreover, since we re-\nviewed only a small number of cases, the success rate may be\ninconsistent with previous data. Among the three cases of\nfailed insertion, it was difficult to advance the catheter into\nthe right subclavian vein with or without the obturator in two\ncases, and advancement of the introducer was impossible in\nthe other case. Reports of common reasons for PICC inser-\ntion failure are difficult to find in the literature, so we could\nnot compare our results with those of previous studies.'),
#  Document(metadata={'type': 'paragraph', 'page': 4, 'text': 'The incidence of malpositioning of the catheter tip is re-\nported to be higher with ultrasound guidance than with fluo-\nroscopic guidance [13] and varies from 8.4% to 27% [10,13]. In\nour study, the malpositioning rate of the inserted cases was\n18.5%, which is consistent with these results. Although we\nchecked via ultrasound immediately after catheter placement,\nupper limb PICC in children may move with arm movement\nto an extent of2.2 rib spaces [14], which can be an explanation\nfor this malpositioning. Abduction of the right upper arm\nduring the procedure might have affected the migration ofthe'}, page_content='The incidence of malpositioning of the catheter tip is re-\nported to be higher with ultrasound guidance than with fluo-\nroscopic guidance [13] and varies from 8.4% to 27% [10,13]. In\nour study, the malpositioning rate of the inserted cases was\n18.5%, which is consistent with these results. Although we\nchecked via ultrasound immediately after catheter placement,\nupper limb PICC in children may move with arm movement\nto an extent of2.2 rib spaces [14], which can be an explanation\nfor this malpositioning. Abduction of the right upper arm\nduring the procedure might have affected the migration ofthe'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'catheter tip since the arm was abducted during the surgery\nand immediate postoperative period. We might have had a\nbetter agreement between CXR and ultrasound if CXR was\nchecked immediately after insertion. However, since we want-\ned to avoid exposing patients to additional radiation, we de-\ncided not to check CXR immediately, but to rely on ultra-\nsound and routine postoperative CXR. This was possible be-\ncause our primary reason for PICC insertion was acquiring a\nstable route of blood sampling and fluid administration, but\nnotmonitoring the central venous pressure.'}, page_content='catheter tip since the arm was abducted during the surgery\nand immediate postoperative period. We might have had a\nbetter agreement between CXR and ultrasound if CXR was\nchecked immediately after insertion. However, since we want-\ned to avoid exposing patients to additional radiation, we de-\ncided not to check CXR immediately, but to rely on ultra-\nsound and routine postoperative CXR. This was possible be-\ncause our primary reason for PICC insertion was acquiring a\nstable route of blood sampling and fluid administration, but\nnotmonitoring the central venous pressure.'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'Immediate complications associated with PICC insertion\nare reported to be rare, with a global complication rate of\n30.2% during indwelling and 11.1 per 1000 PICC-days [15].\nIn our study group, there were no records of any complica-\ntions associated with PICC. In contrast, in our previous\nstudy, patients maintained the PICC for a median of17 days,\nranging from 2 to 174 days [15], and the meantime to the on-\nset of complications was 16.1 days. The relatively short cath-\neter maintenance period may have affected our complica-\ntion-free outcomes. In three cases, however, accidental\nwithdrawal of the catheter occurred during transportation of\nthe patient, which indicated the need for more caution.'}, page_content='Immediate complications associated with PICC insertion\nare reported to be rare, with a global complication rate of\n30.2% during indwelling and 11.1 per 1000 PICC-days [15].\nIn our study group, there were no records of any complica-\ntions associated with PICC. In contrast, in our previous\nstudy, patients maintained the PICC for a median of17 days,\nranging from 2 to 174 days [15], and the meantime to the on-\nset of complications was 16.1 days. The relatively short cath-\neter maintenance period may have affected our complica-\ntion-free outcomes. In three cases, however, accidental\nwithdrawal of the catheter occurred during transportation of\nthe patient, which indicated the need for more caution.'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'Although some reports have described landmark-based\ndetermination of PICC insertion length, they are limited to\nadults [7]. Since there is no standardized method to deter-\nmine the appropriate length of PICC insertion in children\nand no fluoroscopy was available, we simply measured the\ndistance between the targeted insertion site and the sternal\nnotch [7]. The insertion length was optimal in approximately\nhalf of the cases and was acceptable (optimal and subopti-\nmal combined) in 81.5% of the inserted cases. Although\nthere is one report on the landmark-based determination of\nthe length of PICC in children with preliminarily taken CXRs\n[16], we did not employ this technique because of the ab-\nsence of images that cover the right arm and the chest alto-\ngether in our institute.'}, page_content='Although some reports have described landmark-based\ndetermination of PICC insertion length, they are limited to\nadults [7]. Since there is no standardized method to deter-\nmine the appropriate length of PICC insertion in children\nand no fluoroscopy was available, we simply measured the\ndistance between the targeted insertion site and the sternal\nnotch [7]. The insertion length was optimal in approximately\nhalf of the cases and was acceptable (optimal and subopti-\nmal combined) in 81.5% of the inserted cases. Although\nthere is one report on the landmark-based determination of\nthe length of PICC in children with preliminarily taken CXRs\n[16], we did not employ this technique because of the ab-\nsence of images that cover the right arm and the chest alto-\ngether in our institute.'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': "While PICC insertion helps patients in postoperative man-\nagement in many ways, it does not change or help in anes-\nthetic management during surgery. From the anesthesiolo-\ngists' perspective, the advantage of PICC is the relatively\nhigh safety compared to other central venous catheteriza-\ntion methods."}, page_content="While PICC insertion helps patients in postoperative man-\nagement in many ways, it does not change or help in anes-\nthetic management during surgery. From the anesthesiolo-\ngists' perspective, the advantage of PICC is the relatively\nhigh safety compared to other central venous catheteriza-\ntion methods."),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'Our study had some limitations. First, as we only included\nelective surgeries for MMD and patients were relatively\nhealthy except for that, our cases had a relatively short in-\ndwelling duration of PICC and a low complication rate.\nThese may be valuable data, but the findings are not gener-'}, page_content='Our study had some limitations. First, as we only included\nelective surgeries for MMD and patients were relatively\nhealthy except for that, our cases had a relatively short in-\ndwelling duration of PICC and a low complication rate.\nThese may be valuable data, but the findings are not gener-'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'alizable to patients with worse general conditions or those\nrequiring extended indwelling. Further studies including\nother populations are needed to obtain more generalized\ndata. Second, as patient satisfaction was not adequately re-\ncorded and compared to that for conventional central ve-\nnous catheterization, we cannot claim that PICC is more pa-\ntient-friendly than conventional insertions. However, since\nthe median duration of indwelling was approximately 7\ndays, it is credible that the insertion site of the forearm will\nbe much more comfortable to maintain than the neck or\nchest. A prospective study comparing PICC and other meth-\nods of central venous access will provide an answer to this\nconcern. Third, the elapsed time ofinsertion was not record-\ned, even though there were some cases with multiple at-\ntempts. Further prospective studies are required to include\nthe time measurements.'}, page_content='alizable to patients with worse general conditions or those\nrequiring extended indwelling. Further studies including\nother populations are needed to obtain more generalized\ndata. Second, as patient satisfaction was not adequately re-\ncorded and compared to that for conventional central ve-\nnous catheterization, we cannot claim that PICC is more pa-\ntient-friendly than conventional insertions. However, since\nthe median duration of indwelling was approximately 7\ndays, it is credible that the insertion site of the forearm will\nbe much more comfortable to maintain than the neck or\nchest. A prospective study comparing PICC and other meth-\nods of central venous access will provide an answer to this\nconcern. Third, the elapsed time ofinsertion was not record-\ned, even though there were some cases with multiple at-\ntempts. Further prospective studies are required to include\nthe time measurements.'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'In conclusion, PICC can be successfully introduced to pe-\ndiatric patients undergoing surgery for MMD during anes-\nthetic management without serious complications. Further\nprospective studies including insertion depth determina-\ntion, insertion technique, and comparison with other forms\nof central venous access will be needed to improve our clini-\ncal practice for pediatric patients who require central venous\naccess.'}, page_content='In conclusion, PICC can be successfully introduced to pe-\ndiatric patients undergoing surgery for MMD during anes-\nthetic management without serious complications. Further\nprospective studies including insertion depth determina-\ntion, insertion technique, and comparison with other forms\nof central venous access will be needed to improve our clini-\ncal practice for pediatric patients who require central venous\naccess.'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'CONFLICTS OF INTEREST'}, page_content='CONFLICTS OF INTEREST'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'No potential conflict of interest relevant to this article was\nreported.'}, page_content='No potential conflict of interest relevant to this article was\nreported.'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'DATA AVAILABILITY STATEMENT'}, page_content='DATA AVAILABILITY STATEMENT'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'The datasets generated during and/or analyzed during the\ncurrent study are available from the corresponding author\non reasonable request.'}, page_content='The datasets generated during and/or analyzed during the\ncurrent study are available from the corresponding author\non reasonable request.'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'AUTHOR CONTRIBUTIONS'}, page_content='AUTHOR CONTRIBUTIONS'),
#  Document(metadata={'type': 'paragraph', 'page': 5, 'text': 'Conceptualization: Hee-Soo Kim. Data curation: Sang-\nHwan Ji, Sol Ji Yoo, Hee-Soo Kim. Formal analysis: Sol Ji Yoo,\nEun-Hee Kim, Ji-Hyun Lee. Methodology: Young-Eun Jang,\nJin-Tae Kim. Investigation: Sang-Hwan Ji, Sung-Ae Cho, Eun-\nHee Kim, Hee-Soo Kim. Software: Sung-Ae Cho, Young-Eun\nJang, Eun-Hee Kim. Writing - original draft: Sang-Hwan Ji,\nSol Ji Yoo, Sung-Ae Cho, Hee-Soo Kim. Writing - review &\nediting: Sang-Hwan Ji, Young-Eun Jang, Eun-Hee Kim, Ji-\nHyun Lee, Jin-Tae Kim, Hee-Soo Kim.'}, page_content='Conceptualization: Hee-Soo Kim. Data curation: Sang-\nHwan Ji, Sol Ji Yoo, Hee-Soo Kim. Formal analysis: Sol Ji Yoo,\nEun-Hee Kim, Ji-Hyun Lee. Methodology: Young-Eun Jang,\nJin-Tae Kim. Investigation: Sang-Hwan Ji, Sung-Ae Cho, Eun-\nHee Kim, Hee-Soo Kim. Software: Sung-Ae Cho, Young-Eun\nJang, Eun-Hee Kim. Writing - original draft: Sang-Hwan Ji,\nSol Ji Yoo, Sung-Ae Cho, Hee-Soo Kim. Writing - review &\nediting: Sang-Hwan Ji, Young-Eun Jang, Eun-Hee Kim, Ji-\nHyun Lee, Jin-Tae Kim, Hee-Soo Kim.'),
location of periph-\nerally inserted central catheters (PICCs). Pediatr Radiol 2006;\n36: 845-50.\n15. Grau D, Clarivet B, Lotthe A, Bommart S, Parer S. Complica-\ntions with peripherally inserted central catheters (PICCs) used\nin hospitalized patients and outpatients: a prospective cohort\nstudy. Antimicrob Resist Infect Control 2017; 6: 18.\n16. Ramamurthi A, Chick JFB, Srinivasa RN, Hage AN, Grove JJ,\nGemmete JJ, et al. Chest radiograph measurement technique\nfacilitates accurate bedside peripherally inserted central cath-\neter placement in children. Cardiovasc Intervent Radiol 2018;\n41: 443-8.'}, page_content='- 9. Ragasa J, Shah N, Watson RC. Where antecubital catheters go:\n- a study under fluoroscopic control. Anesthesiology 1989; 71:\n- 378-80.\n- 10. Kwon S, Son SM, Lee SH, Kim JH, Kim H, Kim JY, et al. Out-\n- comes of bedside peripherally inserted central catheter place-\n- ment: a retrospective study at a single institution. Acute Crit\n- Care 2020; 35:31-7.\n- 11. Kim YO, Chung CR, Gil E, Park CM, Suh GY, Ryu JA. Safety and\n- feasibility of ultrasound-guided placement of peripherally in-\n- serted central catheter performed by neurointensivist in neu-\n- rosurgery intensive care unit. PLoS One 2019; 14: e0217641.\n- 12. Jumani K, Advani S, Reich NG, Gosey L, Milstone AM. Risk fac-\n- tors for peripherally inserted central venous catheter compli-\n- cations in children. JAMA Pediatr 2013; 167: 429-35.\n- 13. Glauser F, Breault S, Rigamonti F, Sotiriadis C, Jouannic AM,\n- Qanadli SD. Tip malposition of peripherally inserted central\n- catheters: a prospective randomized controlled trial to com-\n- pare bedside insertion to fluoroscopically guided placement.\n- Eur Radiol 2017;27: 2843-9.\n- 14. Connolly B, Amaral J, Walsh S, Temple M, Chait P, Stephens D.\n- Influence of arm movement on central tip location of periph-\n- erally inserted central catheters (PICCs). Pediatr Radiol 2006;\n- 36: 845-50.\n- 15. Grau D, Clarivet B, Lotthe A, Bommart S, Parer S. Complica-\n- tions with peripherally inserted central catheters (PICCs) used\n- in hospitalized patients and outpatients: a prospective cohort\n- study. Antimicrob Resist Infect Control 2017; 6: 18.\n- 16. Ramamurthi A, Chick JFB, Srinivasa RN, Hage AN, Grove JJ,\n- Gemmete JJ, et al. Chest radiograph measurement technique\n- facilitates accurate bedside peripherally inserted central cath-\n- eter placement in children. Cardiovasc Intervent Radiol 2018;\n- 41: 443-8.\n')]

# %% [markdown]
# ### 청킹

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# 청킹 함수 정의
def chunk_documents(documents, chunk_size=500, chunk_overlap=50):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len
    )

    # 새로운 documents 리스트로 청크 생성
    new_documents = []
    
    for doc in documents:
        # page_content에서 청킹
        chunks = text_splitter.split_text(doc.page_content)
        
        # 청크마다 새로운 Document로 생성
        for i, chunk in enumerate(chunks):
            new_doc = Document(
                metadata={
                    #'source': doc.metadata['source'],
                    #'id': f"{doc.metadata['id']}-{i}",  # 각 청크마다 id 변경
                    #'header' : doc.metadata['header'],
                    'type': doc.metadata['type'],
                    'page': doc.metadata['page'],
                    'text': doc.metadata['text']
                    #'paper_title': doc.metadata['paper_title'],
                    #'author': doc.metadata['author']
                },
                page_content=chunk
            )
            new_documents.append(new_doc)
    
    return new_documents

# 청킹 실행
chunked_documents = chunk_documents(documents)

# %%
chunked_documents[0].page_content
# Out:
# '# apm\nANESTHESIA & PAIN MEDICINE'

# %% [markdown]
# ### 임베딩

# %%
! pip install openai pymupdf
# Out:
# Requirement already satisfied: openai in c:\users\user\anaconda3\anaconda\lib\site-packages (1.68.2)
# Requirement already satisfied: pymupdf in c:\users\user\anaconda3\anaconda\lib\site-packages (1.25.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (1.2.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (0.8.2)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (2.10.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (3.5.0)
# Requirement already satisfied: tqdm>4 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\anaconda\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\anaconda\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
! pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\user\anaconda3\anaconda\lib\site-packages (1.68.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (0.8.2)
# Requirement already satisfied: tqdm>4 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (3.5.0)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (1.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai) (2.10.6)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\anaconda\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\anaconda\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
! pip install langchain_openai
# Out:
# Requirement already satisfied: langchain_openai in c:\users\user\anaconda3\anaconda\lib\site-packages (0.3.9)
# Requirement already satisfied: openai<2.0.0,>=1.66.3 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langchain_openai) (1.68.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langchain_openai) (0.9.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langchain_openai) (0.3.45)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_openai) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_openai) (9.0.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_openai) (0.3.19)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_openai) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_openai) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_openai) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_openai) (24.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai<2.0.0,>=1.66.3->langchain_openai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai<2.0.0,>=1.66.3->langchain_openai) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai<2.0.0,>=1.66.3->langchain_openai) (0.28.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai<2.0.0,>=1.66.3->langchain_openai) (3.5.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai<2.0.0,>=1.66.3->langchain_openai) (0.8.2)
# Requirement already satisfied: tqdm>4 in c:\users\user\anaconda3\anaconda\lib\site-packages (from openai<2.0.0,>=1.66.3->langchain_openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\user\anaconda3\anaconda\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2022.7.9)
# Requirement already satisfied: requests>=2.26.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\anaconda\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.66.3->langchain_openai) (3.3)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.66.3->langchain_openai) (1.0.7)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.66.3->langchain_openai) (2025.1.31)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.66.3->langchain_openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\anaconda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain_openai) (3.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain_openai) (0.23.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain_openai) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain_openai) (1.0.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.45->langchain_openai) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.45->langchain_openai) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (1.26.11)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\anaconda\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.66.3->langchain_openai) (0.4.6)

# %%
import os
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 OpenAI API 키 가져오기
api_key = os.getenv("OPENAI_API_KEY")

# OpenAI의 "text-embedding-3-small" 모델을 사용하여 임베딩을 생성
embeddings = OpenAIEmbeddings(model="text-embedding-3-small", openai_api_key=api_key)

# %%
import os
import json

# 임베딩과 메타데이터 저장할 리스트
embedding_data = []
metadata_list = []

# 청킹된 문서 리스트 순회
for idx, doc in enumerate(documents):
    text = doc.page_content  # 청킹된 문서 내용
    metadata = doc.metadata  # 메타데이터

    # OpenAI 임베딩 생성
    embedding = embeddings.embed_query(text)

    # 임베딩 데이터 저장
    embedding_data.append({
        "id": f"chunk_{idx}",  # 고유 ID (추후 Pinecone에 저장 시 사용)
        "embedding": embedding
    })

    # 메타데이터 저장
    metadata_list.append({
        "id": f"chunk_{idx}",
        "metadata": metadata
    })

# JSON 파일로 저장 (임시)
with open("embeddings.json", "w", encoding="utf-8") as f:
    json.dump(embedding_data, f, ensure_ascii=False, indent=4)

with open("metadata.json", "w", encoding="utf-8") as f:
    json.dump(metadata_list, f, ensure_ascii=False, indent=4)

print("✅ 임베딩 & 메타데이터 저장 완료!")
# Out:
# ✅ 임베딩 & 메타데이터 저장 완료!

# %% [markdown]
# ### 파인콘에 적재

# %%
# JSON 파일 경로 (파일이 있는 위치에 맞게 수정!)
embeddings_file = "embeddings.json"
metadata_file = "metadata.json"

# JSON 파일 로드
with open(embeddings_file, "r", encoding="utf-8") as f:
    embeddings_data = json.load(f)

with open(metadata_file, "r", encoding="utf-8") as f:
    metadata_data = json.load(f)

print(f"✅ 임베딩 {len(embeddings_data)}개, 메타데이터 {len(metadata_data)}개 로드 완료!")
# Out:
# ✅ 임베딩 71개, 메타데이터 71개 로드 완료!

# %%
print("🔍 샘플 임베딩 데이터:", embeddings_data[0])  # 첫 번째 벡터 확인
print("🔍 샘플 메타데이터 데이터:", metadata_data[0])  # 첫 번째 메타데이터 확인
# Out:
# 🔍 샘플 임베딩 데이터: {'id': 'chunk_0', 'embedding': [0.019461218267679214, 0.019984591752290726, 0.02458476647734642, 0.022697867825627327, -0.03911525756120682, -0.011479777283966541, 0.0013299532001838088, 0.017836006358265877, 0.00010889260738622397, -0.007953895255923271, -0.025948291644454002, -0.01992950029671192, 0.005120104644447565, 0.02972208708524704, 0.05437571927905083, -0.004266180098056793, 0.046828124672174454, -0.001011453103274107, 0.03677385300397873, 0.014792178757488728, 0.022573910653591156, 0.008277559652924538, -0.0370493121445179, -0.0036567
# 🔍 샘플 메타데이터 데이터: {'id': 'chunk_0', 'metadata': {'type': 'heading1', 'page': 1, 'text': 'apm\nANESTHESIA & PAIN MEDICINE'}}

# %%
import pinecone
#apm-20099_processing.json은 baegjiyeon 파인콘에 적재함!
#전처리 전 json은 ewha 파인콘에 적재하겠음.

# Initialize clients
openai_client = OpenAI(api_key=OPENAI_API_KEY)
#pinecone.init(api_key=PINECONE_API_KEY, environment=PINECONE_ENV)

# Pinecone 인스턴스 생성
pc = Pinecone(api_key=PINECONE_API_KEY)

# 인덱스가 존재하는지 확인 후 연결
existing_indexes = [index["name"] for index in pc.list_indexes()]
if PINECONE_INDEX_NAME not in existing_indexes:
    raise ValueError(f"❌ '{PINECONE_INDEX_NAME}' 인덱스가 존재하지 않습니다. Pinecone에서 생성해주세요!")

# 인덱스 연결
index = pc.Index(PINECONE_INDEX_NAME)

# %%
# Pinecone에 벡터 업로드
vectors_to_upsert = []

for embedding_item, metadata_item in zip(embeddings_data, metadata_data):
    vectors_to_upsert.append({
        "id": embedding_item["id"],  # 고유 ID (chunk ID)
        "values": embedding_item["embedding"],  # 임베딩 벡터 값
        "metadata": metadata_item["metadata"]  # 문서 메타데이터
    })

# Pinecone에 벡터 한 번에 업로드
index.upsert(vectors=vectors_to_upsert)
print(f"✅ {len(vectors_to_upsert)}개 벡터 한 번에 업로드 완료!")
# Out:
# ✅ 71개 벡터 한 번에 업로드 완료!

# %% [markdown]
# ### 리트리버 생성

# %%
! pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\user\anaconda3\anaconda\lib\site-packages (4.49.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (0.29.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: requests in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\anaconda3\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from requests->transformers) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\anaconda\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\anaconda\lib\site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from requests->transformers) (2.0.4)

# %%
! pip install transformers pinecone-client sentence-transformers
# Out:
# Requirement already satisfied: transformers in c:\users\user\anaconda3\anaconda\lib\site-packages (4.49.0)
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\USER\\anaconda3\\anaconda\\Lib\\site-packages\\~-mpy.libs\\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: pinecone-client in c:\users\user\anaconda3\anaconda\lib\site-packages (6.0.0)
# Requirement already satisfied: sentence-transformers in c:\users\user\anaconda3\anaconda\lib\site-packages (3.4.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (0.29.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pinecone-client) (1.26.11)
# Requirement already satisfied: certifi>=2019.11.17 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pinecone-client) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pinecone-client) (2.8.2)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pinecone-client) (0.0.7)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pinecone-client) (4.12.2)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: Pillow in c:\users\user\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (9.2.0)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (1.9.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\anaconda\lib\site-packages (from python-dateutil>=2.5.3->pinecone-client) (1.16.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2.11.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.2.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\anaconda\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\anaconda\lib\site-packages (from scikit-learn->sentence-transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Collecting numpy>=1.17
#   Downloading numpy-1.24.4-cp39-cp39-win_amd64.whl (14.9 MB)
#      --------------------------------------- 14.9/14.9 MB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\anaconda\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.0.1)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4

# %%
! pip install pinecone-client transformers sentence-transformers
# Out:
# Requirement already satisfied: pinecone-client in c:\users\user\anaconda3\anaconda\lib\site-packages (6.0.0)
# Requirement already satisfied: transformers in c:\users\user\anaconda3\anaconda\lib\site-packages (4.49.0)
# Requirement already satisfied: sentence-transformers in c:\users\user\anaconda3\anaconda\lib\site-packages (3.4.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pinecone-client) (1.26.11)
# Requirement already satisfied: certifi>=2019.11.17 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pinecone-client) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pinecone-client) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pinecone-client) (4.12.2)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\users\user\anaconda3\anaconda\lib\site-packages (from pinecone-client) (0.0.7)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (0.29.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (1.24.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: requests in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\user\anaconda3\anaconda\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: Pillow in c:\users\user\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (9.2.0)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (1.9.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\anaconda\lib\site-packages (from python-dateutil>=2.5.3->pinecone-client) (1.16.0)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2.11.3)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.2.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\anaconda\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\anaconda\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\anaconda\lib\site-packages (from scikit-learn->sentence-transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\anaconda\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.0.1)

# %%
from dotenv import load_dotenv
from pinecone import Pinecone
import os
from langchain.vectorstores import Pinecone
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Pinecone as LangchainPinecone
from langchain_community.vectorstores import Pinecone
import pinecone
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import CrossEncoderReranker
from langchain_community.cross_encoders import HuggingFaceCrossEncoder
from langchain_openai import OpenAIEmbeddings

# # OpenAI API 키를 직접 전달
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# index_name지정
index_name = 'boazadv1'

#벡터스토어 
vectorstore = LangchainPinecone(index,embeddings, text_key="text")  # 'text' 필드 지정

#리트리버 생성 
retriever = vectorstore.as_retriever(search_kwargs = {"k":10})

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA
from langchain.chains import ConversationalRetrievalChain
from langchain.prompts import PromptTemplate

#쿼리 실행
query = "During post-insertion chest X-ray evaluation, what radiographic clue strongly suggests that a PICC has entered the internal jugular vein instead of the central circulation?"
relevant_docs = retriever.invoke(query)

#결과
print("Retrieved Douments:")
for doc in relevant_docs:
    print(doc.page_content)

# OpenAI LLM 설정
llm = ChatOpenAI(model_name="gpt-4", openai_api_key=OPENAI_API_KEY)

from langchain_core.prompts import PromptTemplate
# 🔹 프롬프트 정의

custom_prompt = PromptTemplate.from_template(
"""
You are an AI assistant specializing in pediatric anesthesia. 
Your primary task is to provide medically relevant, research-backed responses to assist anesthesiologists.
When responding, follow these guidelines:

1. **Keyword Extraction & Search**:
   - Identify key medical terms in the query.
   - Retrieve relevant data from your knowledge base or provided documents.

2. **Context-Aware Answering**:
   - Provide clear, structured responses based on scientific literature and clinical guidelines.
   - If necessary, list potential differential diagnoses, risk factors, or treatment considerations.

3. **Reference-Based Validation**:
   - Cite relevant sources whenever possible.
   - If the answer is based on general medical knowledge, explicitly state that.

4. **Clinically Usable Information**:
   - Keep responses concise yet informative.
   - Offer actionable insights that a medical professional can apply in practice.

### Example Query:  
*"What are the most common complications of pediatric anesthesia
"*  

### Example Response:  
- **Common Complications**: Postoperative nausea and vomiting (PONV), respiratory depression, bradycardia.  
- **Risk Factors**: Age < 3 years, pre-existing respiratory conditions, opioid use.  
- **Recommended Management**: Preoperative fasting adherence, appropriate opioid titration, intraoperative antiemetic administration.  
- **References**: [Study XYZ, 2023], [Pediatric Anesthesia Guidelines, ASA].  

Now, process the following query and generate a structured response.

Query: {query}
Answer:
""")

# 2. RAG 체인 생성 (stuff 체인에 프롬프트 삽입)
rag_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs={"prompt": custom_prompt}  # 💡 여기에 프롬프트 삽입
)

query = "During post-insertion chest X-ray evaluation, what radiographic clue strongly suggests that a PICC has entered the internal jugular vein instead of the central circulation?"

response = rag_chain.invoke({"query": query})
print("Generated Answer:")
print(response)
# Out:
# Retrieved Douments:
# Conceptualization: Hee-Soo Kim. Data curation: Sang-
# Hwan Ji, Sol Ji Yoo, Hee-Soo Kim. Formal analysis: Sol Ji Yoo,
# Eun-Hee Kim, Ji-Hyun Lee. Methodology: Young-Eun Jang,
# Jin-Tae Kim. Investigation: Sang-Hwan Ji, Sung-Ae Cho, Eun-
# Hee Kim, Hee-Soo Kim. Software: Sung-Ae Cho, Young-Eun
# Jang, Eun-Hee Kim. Writing - original draft: Sang-Hwan Ji,
# Sol Ji Yoo, Sung-Ae Cho, Hee-Soo Kim. Writing - review &
# editing: Sang-Hwan Ji, Young-Eun Jang, Eun-Hee Kim, Ji-
# Hyun Lee, Jin-Tae Kim, Hee-Soo Kim.
# Subject Value
#  Catheter insertion length (cm) 28 (26, 32)
#  Number of attempts to success
#  1 19 (63.3)
#  2 6 (20.0)
#  3 2 (6.7)
#  Reason for failed attempts (n = 17)
#  Venipuncture failure 3 (17.6)
#  Guidewire insertion failure 2 (11.8)
#  Dilation failure 3 (17.6)
#  Catheter advancement failure 9 (52.9)
#  Catheter tip position
#  Optimal* 14 (46.7)
#  Suboptimal† 8 (26.7)
#  Malpositioning‡ 5 (16.7)
#  Failure§ 3 (10.0)
# Catheter insertion technique
# Among the 30 patients, the procedure was completed in
# 27 (90.0%) patients, while we failed to introduce the catheter
# in the other 3 patients. Twenty-two (73.3%) cases showed
# successful PICC with optimal or suboptimal positioning of
# the catheter tip on confirmation with CXR. Insertion was
# successful in the first attempt in 19 patients. Detailed infor-
# mation on the insertion attempts is presented in Table 2(Table 2 summarizes the outcomes of peripherally inserted central catheter (PICC) placement procedures. The median catheter insertion length was 28 cm, with an interquartile range (IQR) of 26 to 32 cm. Regarding the number of attempts required for successful catheter insertion: Success was achieved on the first attempt in 19 cases (63.3%), on the second attempt in 6 cases (20.0%), and on the third attempt in 2 cases (6.7%). Among 17 failed attempts, the reasons were as follows: Venipuncture failure occurred in 3 cases (17.6%), Guidewire insertion failure in 2 cases (11.8%), Dilation failure in 3 cases (17.6%), and Catheter advancement failure was the most common reason, seen in 9 cases (52.9%). In terms of the final catheter tip position: The tip was classified as optimal in 14 cases (46.7%), meaning it was located within 3 cm of the cavoatrial junction. It was suboptimal in 8 cases (26.7%), where the tip was within the superior vena cava (SVC) or the right atrium and could be repositioned easily by slight catheter withdrawal. Malpositioning occurred in 5 cases (16.7%), where the tip was located outside of the SVC. In 3 cases (10.0%), the procedure was classified as a failure, indicating the catheter could not be inserted. All values are presented as median (1st quartile, 3rd quartile) or number with percentage (%), as appropriate.).
# Sang-Hwan Ji', Sol Ji Yoo' Sung-Ae Cho2, Young-Eun Jang1
# Eun-Hee Kim1 Ji-Hyun Lee1 Jin-Tae Kim . and Hee-Soo Kim 1,3
# ,
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13224\3811014086.py in <module>
#      57
#      58 # 2. RAG 체인 생성 (stuff 체인에 프롬프트 삽입)
# ---> 59 rag_chain = RetrievalQA.from_chain_type(
#      60     llm=llm,
#      61     chain_type="stuff",
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain\chains\retrieval_qa\base.py in from_chain_type(cls, llm, chain_type, chain_type_kwargs, **kwargs)
#     113         """Load chain from chain type."""
#     114         _chain_type_kwargs = chain_type_kwargs or {}
# --> 115         combine_documents_chain = load_qa_chain(
#     116             llm, chain_type=chain_type, **_chain_type_kwargs
#     117         )
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain_core\_api\deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     179                 warned = True
#     180                 emit_warning()
# --> 181             return wrapped(*args, **kwargs)
#     182
#     183         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain\chains\question_answering\chain.py in load_qa_chain(llm, chain_type, verbose, callback_manager, **kwargs)
#     263             f"Should be one of {loader_mapping.keys()}"
#     264         )
# --> 265     return loader_mapping[chain_type](
#     266         llm, verbose=verbose, callback_manager=callback_manager, **kwargs
#     267     )
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain\chains\question_answering\chain.py in _load_stuff_chain(llm, prompt, document_variable_name, verbose, callback_manager, callbacks, **kwargs)
#      81     )
#      82     # TODO: document prompt
# ---> 83     return StuffDocumentsChain(
#      84         llm_chain=llm_chain,
#      85         document_variable_name=document_variable_name,
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain_core\_api\deprecation.py in warn_if_direct_instance(self, *args, **kwargs)
#     212                         warned = True
#     213                         emit_warning()
# --> 214                     return wrapped(self, *args, **kwargs)
#     215
#     216                 obj.__init__ = functools.wraps(obj.__init__)(  # type: ignore[misc]
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain_core\load\serializable.py in __init__(self, *args, **kwargs)
#     123     def __init__(self, *args: Any, **kwargs: Any) -> None:
#     124         """"""
# --> 125         super().__init__(*args, **kwargs)
#     126
#     127     @classmethod
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\pydantic\main.py in __init__(self, **data)
#     212         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213         __tracebackhide__ = True
# --> 214         validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215         if self is not validated_self:
#     216             warnings.warn(
#
# ValidationError: 1 validation error for StuffDocumentsChain
#   Value error, document_variable_name context was not found in llm_chain input_variables: ['query'] [type=value_error, input_value={'llm_chain': LLMChain(ve...None, 'callbacks': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/value_error

# %%
# 쿼리 실행
query ="How many cases experienced failure of PICC insertion due to both veins being unsuitable?"
relevant_docs = retriever.invoke(query)

# 결과 출력
print("Retrieved Documents:")
for doc in relevant_docs:
    print(doc.page_content)

# OpenAI LLM 설정
llm = ChatOpenAI(model_name="gpt-4", openai_api_key=OPENAI_API_KEY)

# RAG (Retrieval-Augmented Generation) 모델 생성
rag_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)

# 질의 실행
response = rag_chain.invoke({"query": query})
print("Generated Answer:")
print(response)
# Out:
# Retrieved Documents:
# Conceptualization: Hee-Soo Kim. Data curation: Sang-
# Hwan Ji, Sol Ji Yoo, Hee-Soo Kim. Formal analysis: Sol Ji Yoo,
# Eun-Hee Kim, Ji-Hyun Lee. Methodology: Young-Eun Jang,
# Jin-Tae Kim. Investigation: Sang-Hwan Ji, Sung-Ae Cho, Eun-
# Hee Kim, Hee-Soo Kim. Software: Sung-Ae Cho, Young-Eun
# Jang, Eun-Hee Kim. Writing - original draft: Sang-Hwan Ji,
# Sol Ji Yoo, Sung-Ae Cho, Hee-Soo Kim. Writing - review &
# editing: Sang-Hwan Ji, Young-Eun Jang, Eun-Hee Kim, Ji-
# Hyun Lee, Jin-Tae Kim, Hee-Soo Kim.
# Although some reports have described landmark-based
# determination of PICC insertion length, they are limited to
# adults [7]. Since there is no standardized method to deter-
# mine the appropriate length of PICC insertion in children
# and no fluoroscopy was available, we simply measured the
# distance between the targeted insertion site and the sternal
# notch [7]. The insertion length was optimal in approximately
# half of the cases and was acceptable (optimal and subopti-
# mal combined) in 81.5% of the inserted cases. Although
# there is one report on the landmark-based determination of
# the length of PICC in children with preliminarily taken CXRs
# [16], we did not employ this technique because of the ab-
# sence of images that cover the right arm and the chest alto-
# gether in our institute.
# Among the 30 patients, the procedure was completed in
# 27 (90.0%) patients, while we failed to introduce the catheter
# in the other 3 patients. Twenty-two (73.3%) cases showed
# successful PICC with optimal or suboptimal positioning of
# the catheter tip on confirmation with CXR. Insertion was
# successful in the first attempt in 19 patients. Detailed infor-
# mation on the insertion attempts is presented in Table 2(Table 2 summarizes the outcomes of peripherally inserted central catheter (PICC) placement procedures. The median catheter insertion length was 28 cm, with an interquartile range (IQR) of 26 to 32 cm. Regarding the number of attempts required for successful catheter insertion: Success was achieved on the first attempt in 19 cases (63.3%), on the second attempt in 6 cases (20.0%), and on the third attempt in 2 cases (6.7%). Among 17 failed attempts, the reasons were as follows: Venipuncture failure occurred in 3 cases (17.6%), Guidewire insertion failure in 2 cases (11.8%), Dilation failure in 3 cases (17.6%), and Catheter advancement failure was the most common reason, seen in 9 cases (52.9%). In terms of the final catheter tip position: The tip was classified as optimal in 14 cases (46.7%), meaning it was located within 3 cm of the cavoatrial junction. It was suboptimal in 8 cases (26.7%), where the tip was within the superior vena cava (SVC) or the right atrium and could be repositioned easily by slight catheter withdrawal. Malpositioning occurred in 5 cases (16.7%), where the tip was located outside of the SVC. In 3 cases (10.0%), the procedure was classified as a failure, indicating the catheter could not be inserted. All values are presented as median (1st quartile, 3rd quartile) or number with percentage (%), as appropriate.).
# subclavian vein. In one case, the insertion length was short-
# er than expected to an extent of 5 cm, and there was no ad-
# justment.
# Catheter insertion technique
# CONFLICTS OF INTEREST
# Corresponding author
# Sang-Hwan Ji', Sol Ji Yoo' Sung-Ae Cho2, Young-Eun Jang1
# Eun-Hee Kim1 Ji-Hyun Lee1 Jin-Tae Kim . and Hee-Soo Kim 1,3
# ,
# Outcomes of PICC insertion
# Subject Value
#  Catheter insertion length (cm) 28 (26, 32)
#  Number of attempts to success
#  1 19 (63.3)
#  2 6 (20.0)
#  3 2 (6.7)
#  Reason for failed attempts (n = 17)
#  Venipuncture failure 3 (17.6)
#  Guidewire insertion failure 2 (11.8)
#  Dilation failure 3 (17.6)
#  Catheter advancement failure 9 (52.9)
#  Catheter tip position
#  Optimal* 14 (46.7)
#  Suboptimal† 8 (26.7)
#  Malpositioning‡ 5 (16.7)
#  Failure§ 3 (10.0)
# Generated Answer:
# {'query': 'How many cases experienced failure of PICC insertion due to both veins being unsuitable?', 'result': 'The text does not provide information on the number of cases where PICC insertion failed due to both veins being unsuitable.'}

# %%
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate

# 프롬프트 정의: 문서와 질문을 기반으로 명확한 답변을 유도
prompt_template = """
You are a medical assistant helping to analyze clinical research data.

Use the following context extracted from a study to answer the question as precisely as possible.
If the answer is not contained in the context, say "The context does not provide an answer."

--------------------
Context:
{context}
--------------------

Question: {query}

Answer in one sentence:
"""

custom_prompt = PromptTemplate(
    input_variables=["context", "query"],
    template=prompt_template,
)

# OpenAI 모델 설정
llm = ChatOpenAI(model_name="gpt-4", openai_api_key=OPENAI_API_KEY)

# Retrieval QA 체인 구성
rag_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type="stuff",
    chain_type_kwargs={"prompt": custom_prompt},
    return_source_documents=True  # 어디서 답을 가져왔는지도 확인할 수 있게 설정
)

# 질의 실행
query = "How many cases experienced failure of PICC insertion due to both veins being unsuitable?"
response = rag_chain.invoke({"query": query})

# 결과 출력
print("Generated Answer:")
print(response["result"])  # 결과만 보기

print("\nSource Document(s):")
for doc in response["source_documents"]:
    print(doc.page_content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13224\1139981616.py in <module>
#      39 # 질의 실행
#      40 query = "How many cases experienced failure of PICC insertion due to both veins being unsuitable?"
# ---> 41 response = rag_chain.invoke({"query": query})
#      42
#      43 # 결과 출력
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain\chains\base.py in invoke(self, input, config, **kwargs)
#     168         except BaseException as e:
#     169             run_manager.on_chain_error(e)
# --> 170             raise e
#     171         run_manager.on_chain_end(outputs)
#     172
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain\chains\base.py in invoke(self, input, config, **kwargs)
#     158             self._validate_inputs(inputs)
#     159             outputs = (
# --> 160                 self._call(inputs, run_manager=run_manager)
#     161                 if new_arg_supported
#     162                 else self._call(inputs)
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain\chains\retrieval_qa\base.py in _call(self, inputs, run_manager)
#     152         else:
#     153             docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 154         answer = self.combine_documents_chain.run(
#     155             input_documents=docs, question=question, callbacks=_run_manager.get_child()
#     156         )
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain_core\_api\deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     179                 warned = True
#     180                 emit_warning()
# --> 181             return wrapped(*args, **kwargs)
#     182
#     183         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain\chains\base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     609
#     610         if kwargs and not args:
# --> 611             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     612                 _output_key
#     613             ]
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain_core\_api\deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     179                 warned = True
#     180                 emit_warning()
# --> 181             return wrapped(*args, **kwargs)
#     182
#     183         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain\chains\base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     387         }
#     388
# --> 389         return self.invoke(
#     390             inputs,
#     391             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain\chains\base.py in invoke(self, input, config, **kwargs)
#     168         except BaseException as e:
#     169             run_manager.on_chain_error(e)
# --> 170             raise e
#     171         run_manager.on_chain_end(outputs)
#     172
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain\chains\base.py in invoke(self, input, config, **kwargs)
#     156         )
#     157         try:
# --> 158             self._validate_inputs(inputs)
#     159             outputs = (
#     160                 self._call(inputs, run_manager=run_manager)
#
# c:\Users\USER\anaconda3\anaconda\lib\site-packages\langchain\chains\base.py in _validate_inputs(self, inputs)
#     288         missing_keys = set(self.input_keys).difference(inputs)
#     289         if missing_keys:
# --> 290             raise ValueError(f"Missing some input keys: {missing_keys}")
#     291
#     292     def _validate_outputs(self, outputs: Dict[str, Any]) -> None:
#
# ValueError: Missing some input keys: {'query'}
