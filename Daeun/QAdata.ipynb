# %%
# 📄 PDF 문서
#    ↓ (Upstage DocumentParser)
# 📜 전체 텍스트
#    ↓ (페이지 단위 청킹)
# 🧩 context 청크들
#    ↓ (GPT-4 API 호출, 커스텀 프롬프트로 질문/정답/이유 생성/CoT Reasoning)
# 📦 question / context / reason & answer /
#    ↓
# 💾 QA datasets csv 저장 (RAFT fine-tuning에 사용)

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## RAFT 학습용 QA 생성기

# %%
import re
import os
import requests
import json
from tqdm import tqdm
import openai
from langchain_core.documents import Document

# %%
# ✅ 파일 경로 설정
file_path = r"/Users/daeunbaek/nuebaek/BOAZ/BOAZ_ADV/Daeun/apm_guidelines/APM-11-055.pdf"
file_name = os.path.basename(file_path)
output_path = os.path.join(os.path.dirname(file_path), f"{os.path.splitext(file_name)[0]}.json")

# %%
import os
import requests
import json

# ✅ 기본 요청 설정
DEFAULT_CONFIG = {
    "ocr": False,
    "coordinates": True,
    "output_formats": "['html', 'text', 'markdown']", 
    "model": "document-parse",
    "base64_encoding": "['figure', 'chart', 'table']" 
}

# ✅ Upstage API 설정
api_url = "https://api.upstage.ai/v1/document-ai/document-parse"
api_key = os.environ.get("UPSTAGE_API_KEY")
headers = {"Authorization": f"Bearer {api_key}"}

# ✅ 분석 요청 실행
print(f"📤 파일 업로드 중: {file_name}")
with open(file_path, "rb") as pdf:
    response = requests.post(
        api_url,
        headers=headers,
        data=DEFAULT_CONFIG,
        files={"document": pdf}
    )

# ✅ 결과 처리 및 metadata 추가 저장
if response.status_code == 200:
    result = response.json()
    
    # 📎 메타데이터 구성
    metadata = {
        "document_name": file_name,
        "model": result.get("model"),
        "usage": result.get("usage"),
        "num_pages": len({elem["page"] for elem in result.get("elements", [])}),
    }

    # 결과와 메타데이터를 함께 저장
    result_with_metadata = {
        "metadata": metadata,
        "elements": result.get("elements", [])
    }

    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(result_with_metadata, f, ensure_ascii=False, indent=2)
    
    print(f"✅ 분석 결과 및 메타데이터 저장 완료: {output_path}")
else:
    print(f"❌ 오류 발생 ({response.status_code}): {response.text}")
# Out:
# 📤 파일 업로드 중: APM-11-055.pdf
# ✅ 분석 결과 및 메타데이터 저장 완료: /Users/daeunbaek/nuebaek/BOAZ/BOAZ_ADV/Daeun/apm_guidelines/APM-11-055.json

# %%
# ✅ 분석 결과 JSON 파일 경로
json_path = "/Users/daeunbaek/nuebaek/BOAZ/BOAZ_ADV/Daeun/apm_guidelines/APM-11-055.json"

# %%
# ✅ 분석 결과 JSON 파일 경로
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

elements = data["elements"]

# ✅ 페이지 필터링 + 문단 추출
# remove_pages = set(range(0, 5)) | set(range(63, 68))

filtered_elements = [
    elem for elem in elements
    if elem["category"] not in ("footer", "header", "footnote")
    # and elem["page"] not in remove_pages
    and elem["content"].get("markdown", "").strip()
]

# %%
# 제거할 페이지 필터링 + 문단 결합
from langchain_core.documents import Document

# remove_pages = set(range(0, 35)) | set(range(57, 69))  # 필요 없는 페이지 번호 제거
page_map = {}
for elem in elements:
    page = elem["page"]
    if elem["category"] in ("footer", "header", "footnote"):
        continue
    text = elem["content"].get("markdown", "").strip()
    if text:
        page_map[page] = page_map.get(page, "") + "\n" + text

# %%
#LangChain Document 구성
documents = [
    Document(
        page_content=page_map[page].strip(),
        metadata={"page": page, "document_name": file_name}
    )
    for page in sorted(page_map.keys())
]

print(f"✅ 구성된 문서 수: {len(documents)}")
]
# Out:
# ✅ 구성된 문서 수: 6

# %%
# split_docs는 페이지 단위로 그대로 사용
split_docs = documents
print(f"✅ QA 생성을 위한 페이지 청크 수: {len(split_docs)}")
# Out:
# ✅ QA 생성을 위한 페이지 청크 수: 6

# %%
split_docs
# Out:
# [Document(metadata={'page': 1, 'document_name': 'APM-11-055.pdf'}, page_content='Anesth Pain Med 2016; 11: 55-63\nhttp://dx.doi.org/10.17085/apm.2016.11.1.55\nPharmacological and non-pharmacological interventions to\nalleviate anxiety before pediatric anesthesia: a survey of\ncurrent practice in Korea\nDepartment of Anesthesiology and Pain Medicine, Yeungnam University School of Medicine, *Kyungpook National University School of\nMedicine, Daegu, Korea\nHyo Eun Kang, Sung Mee Jung, and Sungsik Park*\nBackground: This study was undertaken to determine current\npractice for preoperative anxiety reduction in Korean children.\nMethods: An email survey of all members (n = 158) of the Korean\nSociety of Pediatric Anesthesiologists was conducted from\nNovember 2014 to January 2015 to assess current practice,\npreferences, and general opinions regarding pharmacological and\nnon-pharmacological interventions performed to alleviate preoperative\nanxiety in children prior to general anesthesia.\nResults: Forty-one anesthesiologists completed the survey; a\nresponse rate of 26%. Only 4.9% of respondents undertook anxiety\nreduction according to a written hospital policy, and 95.1% did not.\nMost respondents (70.7%) performed anxiolytic intervention guided\nby informally standardized hospital protocol. In clinical practice,\n90% of respondents used pharmacological and/or non-pharma-\ncological intervention to alleviate anxiety in children. Nearly half\nof the respondents (53.7%) used premedication to reduce anxiety,\nand midazolam was most frequently used. Parental presence during\ninduction of anesthesia was considered the most effective\nnon-pharmacological intervention (60.4%), and was allowed by 78%\nof respondents, and watching a video was considered the second\nmost effective intervention (27.1%).\nConclusions: Korean pediatric anesthesiologists use both phar-\nmacological and non-pharmacological interventions to alleviate\npreoperative anxiety, and these interventions are generally guided\nby an informally standardized hospital protocol. Anesthesiologists\nrequiring effective anxiety reduction prefer pharmacological interven-\ntion and most commonly use intravenous midazolam, whereas those\nthat want safe anxiety reduction prefer non-pharmacological\nReceived: June 24, 2015.\nRevised: September 3, 2015.\nAccepted: September 21, 2015.\nCorresponding author: Sung Mee Jung, M.D., Department of Anesthesiology\nand Pain Medicine, Yeungnam University School of Medicine, 170,\nHyeonchung-ro, Nam-gu, Daegu 42415, Korea. Tel: 82-53-620-3368, Fax:\n82-53-626-5275, E-mail: applejsm@gmail.com\nThis is an Open Access article distributed under the terms of the Creative Commons\nAttribution Non-Commercial License (http://creativecommons.org/licenses/by-nc/4.0)\nwhich permits unrestricted non-commercial use, distribution, and reproduction in any\nmedium, provided the original work is properly cited.\nintervention and most frequently use parental presence during\ninduction of anesthesia. (Anesth Pain Med 2016; 11: 55-63)\nKey Words: Anesthesia, Anxiety, Pediatrics, Policy, Premedication,\nPreoperative period.\nINTRODUCTION\nA significant number of young children undergoing general\nanesthesia experience high levels of preoperative anxiety caused\nby separation from parents, exposure to an unfamiliar envi-\nronment, or fear of the surgical procedure. Because preoperative\nanxiety can complicate the induction of anesthesia and develop\nnegative postoperative behavior [1,2], pediatric anesthesiologists\ngenerally use a variety of interventions to reduce preoperative\nanxiety in children. Surveys conducted in different countries\nhave documented the frequencies of and the reasons for\nanxiolytic interventions in pediatric patients [3-7]. However, no\nsuch study has been previously conducted in Korea. In\naddition, practices have changed over decades due to the\nintroductions of short-acting anesthetics with fewer side effects,\nadvances in distraction t ...
#  Document(metadata={'page': 2, 'document_name': 'APM-11-055.pdf'}, page_content='\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\nTable 1. Questionnaire Sections\n- 1. Respondent demographics\n- Age, gender, subspecialty, type of hospital work, practicing region.\n- 2. Preference and guideline for anxiolytic intervention in pediatric anesthesia\n- Presence of a written policy, preference for pharmacological and non-pharmacological interventions and actual use in clinical practice\n- 3. General opinions and practices regarding pharmacological intervention for anxiety reduction\n- Premedication regimen and route of administration, side effects of concern and those experienced, a beliefs concerning the need\n- routine anticholinergic use\n- 4. General opinions and practices of non-pharmacological intervention for anxiety reduction\n- Non-pharmacological intervention used in practice and preferred and attitude to parental presence during induction of anesthesia\ngeneral opinions regarding perioperative anxiety reduction in\nKorean children from November 2014 to January 2015. The\nquestionnaire with an explanation of this survey and its sig-\nnificance was emailed to all members (n = 158) of the KSPA\nin November and a reminder email was sent in December\n2014 by the KSPA to ensure personal privacy. Completion of\nthe questionnaire by the participants was conducted on a\nvoluntary, anonymous basis.\nThe survey (Appendix 1) consisted of 1 open and 23 closed\nquestions in four sections (Table 1), which addressed; 1)\nrespondent demographics, 2) preferences and guidelines for\nanxiolytic intervention prior to pediatric anesthesia, 3) general\nopinions and practices of pharmacological intervention for\nanxiety reduction, and 4) general opinions and practices of\nnon-pharmacological intervention for anxiety reduction.\nStatistical analysis was performed using SPSS version 21.0\n(IBM Corporation, New York, NY, USA). Descriptive variables\nare reported as means ± SDs or as medians and ranges. For\ncategorical variables, both single and multiple response\nquestions are reported as numbers (%) of all responses. The\nrespondent demographics were analyzed using the one sample\nt-test and the chi-square test or Fischer’s exact test. Statistical\nsignificance was accepted for P values ＜ 0.05.\nRESULTS\nDemographics of respondents\nForty-one of the 158 members of the KSPA participated in\nthe survey; an overall response rate of 26%. The characteristics\nof pediatric anesthesiologists who responded to the survey are\nsummarized in Table 2. Respondents were typically in their\nforties (39%), the gender ratio was almost 1 : 1 (males 46.3%\nand females 53.7%), and they had been in practice for 14.4 ±\n8.4 years. Most of them (85.4%) worked at tertiary hospital.\nRespondents usually anesthetized inpatients (84.6%); followed\nTable 2. Demographics of Respondents\n| Char ...
#  Document(metadata={'page': 3, 'document_name': 'APM-11-055.pdf'}, page_content='\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\nanxiety according to a written hospital policy. Majority of\nrespondents (70.7%) performed anxiolytic interventions according\nto an informally standardized hospital protocol (habitual choice\ngenerally accepted in their hospital and learned by word of\nmouth).\nPreferences and actual practice regarding phar-\nmacological and non-pharmacological interventions\nNon-pharmacological intervention (46.3%) was preferred to\npremedication (39.0%) to reduce preoperatively anxiety. Small\nproportion of respondents (14.6%) stated they had no preference.\nThe three most common reasons given to support preference\nwere effectiveness (32.0%), concern about side effects (26.0%),\nand convenience (24.0%, Table 3). However, these reasons\nwere found to depend on anxiolytic preferences, that is, effec-\ntiveness was favored by those who preferred pharmacological\nintervention, and concern about side effects was favored by\nthose who preferred non-pharmacological intervention.\nActually used intervention for reducing anxiety in clinical\npractice were significantly different according to the anxiolytic\npreference (P = 0.005) but they did not consistently match\neach other (Table 4). Overall, non-pharmacological intervention\nand premedication were actually performed by 36.6 and 24.4%\nof the respondents, respectively, in clinical practice. Both were\nused by 29.3% and neither was used by 9.8% of the\nrespondents.\nCurrent practice and general opinions regarding\npharmacological anxiolytic intervention in pediatric\npatients\nAbout half of the respondents (53.7%) reported use of\npremedication prior to surgery as single intervention or\ncombination with non-pharmacological intervention. However,\nthe other respondents (46.3%) stated they were unlikely to use\npremedication in practice because of needlessness of premedication\n(42.1%), concern about side effects (31.5%) and invasiveness\nof administration (21.5%).\nReducing child anxiety (63.4%) and control of sympathetic\nactivity (17.1%) were reported to be the two most important\nreasons for premedication. Reducing parental anxiety, pain\ncontrol, and improving cooperation during induction of\nanesthesia tied as the third most important reasons (each\n9.8%). Age limitation to premedication was applied by 39.0%\nof respondents. Although minimum age for premedication\nranged from 1 month to 5 years, majority of respondents\n(68.8%) adopted a minimum age of 1 year.\nDrug selection for premedication was guided by customarily\nuse (45.1%), the literature (17.1%), and effectiveness (14.6%).\nTable 3. Reasons for Anxiolytic Intervention Preferences in Pediatric Patients\n|  | Non-pharmacological | Pharmacological preference | No preference | Overall |\n| --- | --- | --- | --- | --- |\n|  |  ...
#  Document(metadata={'page': 4, 'document_name': 'APM-11-055.pdf'}, page_content='\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\nOf all responses, the most frequently used premedication was\nmidazolam (24.7%) followed by ketamine (20.3%) when\nmultiple responses were allowed by the respondent (Table 5).\nThe use of anticholinergic premedication for children undergoing\nsurgery was considered routinely by 24.4%, occasionally by\n34.1% and as unnecessary by 39.0% of the respondents.\nPremedication was administered in the preoperative holding\narea (54.7%), in the ward (24.5%), or in the operating room\n(20.8%). Intravenous administration was usually preferred to\nTable 5. Premedication of Pediatric Patients before Elective Surgery\n| Premedication | Route | Number (%) |\n| --- | --- | --- |\n| Midazolam | IV | 19 (21.3) |\n|  | IM | 3 (3.4) |\n| Ketamine | IV | 15 (16.9) |\n|  | IM | 3 (3.4) |\n| Glycopyrrolate | IV | 14 (15.7) |\n|  | IM | 4 (4.5) |\n| Atropine | IV | 9 (10.1) |\n|  | IM | 3 (3.4) |\n| Thiopental | IV | 8 (9.0) |\n| Propofol | IV | 3 (3.4) |\n| Diazepam | IV | 1 (1.1) |\n| Fentanyl | IV | 4 (4.5) |\n| Dexmedetomidine | IV | 2 (2.2) |\n| Meperidine | IV | 1 (1.1) |\n| All responses |  | 89 (100) |\nMultiple responses are possible. Values are expressed as numbers\n(%) of all responses. IV: intravenous administration, IM: intramuscular\nadministration.\nintramuscular administration. Children that remained anxious\ndespite premedication were usually managed with an intravenous\nanesthetic (61%) or by PPIA (31.7%).\nRespiratory depression was the side effect of most concern\n(53.7%) when considering use of premedication, and was also\nthe most commonly experienced side effect (22.0%). Other side\neffects actually experienced by respondents were overexcitement\n(14.6%), injection pain (12.2%), delayed recovery after anesthesia\n(9.8%), and nausea and vomiting (2.4%). However, 20% of\nrespondents report no adverse event after premedication.\nCurrent practice and general opinions regarding\nnon-pharmacological anxiolytic intervention in pe-\ndiatric patients\nThe respondents replied that PPIA, watching a video using a\nhand-held electronic device, such as, a smartphone or personal\ncomputer, and conversation effectively reduced anxiety prior to\nsurgery (Table 6). On the other hand, reading books, an\noperating room tour, hypnosis, and the use of clowns were\nreported to be ineffective.\nPPIA was allowed on a case by case basis by 78% of the\nrespondents, but was absolutely forbidden by 19.5% of them.\nRespondents used PPIA to prevent separation anxiety (65.0%),\nto induce volatile anesthesia smoothly (20.0%), and to reduce\nparental anxiety (15.0%). On the contrary, respondents forbade\nPPIA to maintain stability of the operating room environment\n(46.2%) and to prevent transmission of anxiety from parents to\nchildren (30.8%) and used ...
#  Document(metadata={'page': 5, 'document_name': 'APM-11-055.pdf'}, page_content='\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\n# non-pharmacological interventional means.\nDISCUSSION\nThis small-scale survey offers insights of current practice\nand the general opinions of pediatric anesthesiologists regarding\npreoperative anxiolytic interventions in children undergoing\nsurgery in Korea. We found that the strategies used to reduce\nchild anxiety were determined by an informally standardized\nhospital protocol or individual experience rather than a written\npolicy. In contrast, 72% of US hospitals have a formal policy\nfor premedication [3]. Without current best evidence, preoperative\nanxiolytic intervention based on hospital protocol may become\ndated, to the detriment of patients. In our opinion, decision\nmaking should be guided by formal policy integrated with\nindividual clinical expertise and best available scientific\nevidence to ensure children are provided with the most\neffective and safe anxiolytic intervention.\nAlthough many non-pharmacological interventions have been\nreported to be as effective as sedative premedication [8],\nrespondents who wanted effective anxiolysis preferred phar-\nmacological intervention, while those who wanted safe anxiolysis\npreferred non-pharmacological intervention. Our finding implies\nthat anxiolytic intervention preference of pediatric anesthesiologists\nwas usually determined by customarily established protocol or\nhabitual choice rather than scientific research. And it also\nexplains why actually used interventions did not consistently\nmatch with preferred interventions. The two most important\npurposes of premedication are to reduce anxiety and sympathetic\nactivity during induction of anesthesia. In Korea, the sedative\npremedication rate for pediatric anesthesia (54.7%), as determined\nby the present study, is similar to those reported in Turkey,\nGermany, and the United States [5,9,10], but is much higher\nthan reported in the United Kingdom for day-case surgery\n(19%) [7]. Although numerous drugs have been used in\nclinical practice, midazolam is currently the mainstay of\nsedative premedication for pediatric anesthesia. Its long history\nof safety, effectiveness, and minimal delay to discharge from\npost-anesthesia care unit well explain its global use in clinical\npractice. Because oral or intranasal midazolam, commonly used\nas a premedication in Europe and the US [5,9], is not\ncurrently available in Korea, respondents mostly administered\nmidazolam intravenously in the preoperative holding area.\nThe routine use of anticholinergic agents prior to anesthesia\nand surgery now shows a declining tread, because of its\nadverse effects, such as, an uncomfortable dryness of mouth,\nand the introduction of less irritating anesthetics [11,12]. In the\npresent study, respondents premedicated a ...
#  Document(metadata={'page': 6, 'document_name': 'APM-11-055.pdf'}, page_content="\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\U000f080f\nwanting safe reduction of anxiety preferred non-pharmacological\nintervention and most frequently used parental presence during\ninduction the anesthesia.\nACKNOWLEDGEMENTS\nThe authors thank professor Hee-Soo Kim and Byung Gun\nLim, president and director of academic affairs, respectively, of\nthe Korean Society of Pediatric Anesthesiologists (KSPA) for\nreviewing our survey questionnaire, granting permission to\nsurvey KSPA members and forwarding the e-mail responses.\nWe also appreciate for all KSPA members who completed the\nsurvey.\nREFERENCES\n- 1. Kotiniemi LH, Ryhanen PT, Moilanen IK. Behavioural changes\n- in children following day-case surgery: a 4-week follow-up of 551\n- children. Anaesthesia 1997; 52: 970-6.\n- 2. Kain ZN, Mayes LC, O'Connor TZ, Cicchetti DV. Preoperative\n- anxiety in children. Predictors and outcomes. Arch Pediatr Adolesc\n- Med 1996; 150: 1238-45.\n- 3. Kain ZN, Mayes LC, Bell C, Weisman S, Hofstadter MB, Rimar\n- S. Premedication in the United States: a status report. Anesth\n- Analg 1997; 84: 427-32.\n- 4. Mirakhur RK. Preanaesthetic medication: a survey of current\n- usage. J R Soc Med 1991; 84: 481-3.\n- 5. Haas U, Motsch J, Schreckenberger R, Bardenheuer HJ, Martin\n- E. Premedication and preoperative fasting in pediatric anesthesia.\n- Results of a survey. Anaesthesist 1998; 47: 838-43.\n- 6. Nagahama H, Yagi K, Noda M, Hara K, Kikuchi S, Nagatsu M,\net al. A survey of opioid use in preanesthetic medication. Masui\n- 1998; 47: 1373-6.\n- 7. Payne K, Moore EW, Elliott RA, Moore JK, McHugh GA.\n- Anaesthesia for day case surgery: a survey of paediatric clinical\n- practice in the UK. Eur J Anaesthesiol 2003; 20: 325-30.\n- 8. Yip P, Middleton P, Cyna AM, Carlyle AV. Non-pharmacological\n- interventions for assisting the induction of anaesthesia in children.\n- Cochrane Database Syst Rev 2009; (3): CD006447.\n- 9. Kain ZN, Caldwell-Andrews AA, Krivutza DM, Weinberg ME,\n- Wang SM, Gaal D. Trends in the practice of parental presence\n- during induction of anesthesia and the use of preoperative sedative\n- premedication in the United States, 1995-2002: results of a\n- follow-up national survey. Anesth Analg 2004; 98: 1252-9.\n- 10. Esener Z, Ustun E. Epidemiology in pediatric anesthesia. A\n- computerized survey of 10,000 anesthetics. Turk J Pediatr 1994;\n- 36: 11-9.\n- 11. Rautakorpi P, Ali-Melkkila T, Kanto J. Anticholinergic drugs in\n- paediatric anaesthesia. A survey of their present position in Finland\n- 1990. Ann Chir Gynaecol 1994; 83: 64-8.\n- 12. Rautakorpi P, Manner T, Kanto J. A survey of current usage of\n- anticholinergic drugs in paediatric anaesthesia in Finland. Acta\n- Anaesthesiol Scand 1999; 43: 1057-9.\n- 13. Parnis SJ, van der Walt JH. A national survey of atro ...

# %%
# prompt

# from langchain_core.prompts import PromptTemplate
# from langchain_openai import ChatOpenAI
# from langchain_core.output_parsers import StrOutputParser
# from langchain_core.runnables import RunnableLambda
# from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
# import json
# import difflib

# prompt = PromptTemplate.from_template(
#     """Context information is below. You are only aware of this context and nothing else.

# ### Context:
# ---------------------
# {context}
# ---------------------

# You are a medical expert in the field of {domain}. Based on the above clinical guideline context, your task is to generate exactly {num_questions} question(s) that a medical professional might ask to assess clinical understanding.

# ---

# Each Q&A pair must:
# - Present a **clinically plausible and distinct** question (no duplicates or variations of the same question)
# - Be grounded **explicitly in the given context** (no hallucinations)
# - Belong to one of the following clinical reasoning categories:
#   • Drug selection & dosing (e.g., appropriate drug, route, weight-based dosing)
#   • Contraindications & precautions
#   • Sedation monitoring & depth assessment
#   • Pre-sedation evaluation
#   • Recovery & discharge criteria
#   • Emergency management

# ---

# To add clinical realism, consider:
# - Comorbidities
# - Risk-benefit tradeoffs
# - Dosing adjustments or monitoring strategies

# ---

# Each entry must include:
# - `question`: A Korean clinical question
# - `reason`: A Korean explanation citing direct quotes using ##begin_quote## and ##end_quote##
# - `answer`: A Korean answer based strictly on the context

# To ensure quality:
# - Do not repeat medications, topics, or sentence structures
# - Vary the structure of your reasoning to avoid templated style

# Respond only in **valid JSON array format**. No markdown, no lists, no extra explanations.

# ---

# ### Example Format:
# [
#   {{
#     "question": "4살 환자의 적절한 endotracheal tube size와 depth는?",
#     "reason": "문서에 따르면 ##begin_quote## ETT 크기(직경, mm) = (나이/4) + 4 / 깊이(cm) = (나이/2) + 12 ##end_quote## 라고 명시되어 있습니다.",
#     "answer": "비커프 튜브는 5.0 mm, 커프 튜브는 4.5 mm, 깊이는 약 14 cm가 적절합니다."
#   }},
#   {{
#     "question": "소아 환자를 깨울 때 laryngospasm이 의심되면 어떻게 해야 하나요?",
#     "reason": "문서에서는 ##begin_quote## 후두경련 발생 시 양압환기, 하악 자극, 약물 투여, 기도 확보가 필요하다 ##end_quote## 라고 명시되어 있습니다.",
#     "answer": "산소 양압환기, 하악 자극, 프로포폴 또는 석시닐콜린 투여, 필요시 재삽관을 고려합니다."
#   }}
# ]
# """
# )

# %%
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnableLambda
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# Removed unnecessary import of convert_to_openai_image_block
from tqdm import tqdm
import difflib
import json
import re
import os
import pandas as pd

# ✅ 1. 프롬프트 템플릿 정의
medical_qa_prompt_template = PromptTemplate.from_template(medical_qa_prompt_template = """
# Role and Objective
You are a specialized medical expert in Pediatric Anesthesia.
Your primary task is to generate high-quality Korean Q&A data from provided medical guidelines for training a medical question-answering model.

# Core Principles
- Maintain strict medical accuracy and precision
- Focus on practical clinical scenarios
- Ensure questions are specific and actionable
- Include relevant numerical values when available
- Generate questions only from provided context
- Use clear and professional Korean language

# Input Data Structure
{
    "context": {context},
    "num_questions per page": {num_questions}
}

# Question Generation Guidelines
1. Content Adherence:
   - Generate questions strictly based on provided content
   - Include specific numerical values (doses, weights, ages, etc.)
   - Focus on practical clinical applications

2. Question Format:
   - Use open-ended, short-answer format
   - Write questions in Korean
   - Make questions specific and clinically relevant
   - Avoid multiple-choice formats

3. Reference Requirements:
   - Include all supporting sentences
   - For tables: include entire table content
   - For figures: include surrounding text and captions

# Answer Guidelines
- Start reasoning directly with a quote 
- Start with a step-by-step reasoning using quotes from the context
- Enclose all direct quotes in **##begin_quote## ... ##end_quote##**
- End with `<ANSWER>: ...` in Korean (full sentence) 

# Output Format
Return your output in this **strict JSON format**:
[
  {
    "question": "한국어로 된 의학 질문",
    "reference_sentences": [
      "관련 문장 1",
      "관련 문장 2"
    ],
    "answer": "##Reason: ...\n<ANSWER>: ..."
  }
]

# Quality Controls
- Ensure medical accuracy
- Verify all numerical values
- Check Korean language usage
- Validate JSON format
- Confirm reference alignment

# Error Prevention
- Double-check medical terminology
- Verify numerical calculations
- Ensure proper Korean grammar
- Validate JSON structure
- Confirm context alignment

# Example Outputs
Return as a **valid JSON array** of objects. Each object must look like:

[
  {{
    "question": "5살 23kg 소아 환자의 마취 중 적절한 수액 주입량은?",
    "reference_sentences": [
      "20kg을 초과하는 소아의 유지 수액량은 첫 20kg에 대해 1500mL를 적용하고, 이후 1kg당 20mL를 추가로 계산한다.",
      "이 수액량은 전신마취 중 적절한 수분 공급을 위해 사용된다."
    ],
    "answer": "##Reason: 문서의 ##begin_quote## 20kg을 초과하는 소아의 유지 수액량은 첫 20kg에 대해 1500mL를 적용하고, 이후 1kg당 20mL를 추가로 계산한다 ##end_quote## 라는 설명에 따르면, 23kg 소아는 1500mL + (3×20mL) = 1560mL가 필요합니다.\n<ANSWER>: 5살 23kg 소아의 마취 중 유지 수액량은 1560mL입니다."
  }},
  {{
    "question": "소아 환자를 깨울 때 laryngospasm이 의심되면 어떤 처치를 해야 하나요?",
    "reference_sentences": [
      "Laryngospasm이 의심되는 경우 즉각적인 처치로는 jaw thrust, 양압 환기, 그리고 succinylcholine 투여가 포함된다.",
      "신속한 인식과 처치가 저산소증을 예방하는 데 중요하다."
    ],
    "answer": "##Reason: 문서에 따르면 ##begin_quote## 즉각적인 처치로는 jaw thrust, 양압 환기, 그리고 succinylcholine 투여가 포함된다 ##end_quote## 라고 되어 있습니다. 이는 환자의 기도를 유지하고 저산소증을 방지하는 데 중요한 조치입니다.\n<ANSWER>: Laryngospasm이 의심되는 경우 jaw thrust, 양압 환기, succinylcholine 투여를 포함한 즉각적인 처치가 필요합니다."
  }}
]
"""
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 15
#      12 import pandas as pd
#      14 # ✅ 1. 프롬프트 템플릿 정의
# ---> 15 medical_qa_prompt_template = PromptTemplate.from_template(medical_qa_prompt_template = """
#      16 # Role and Objective
#      17 You are a specialized medical expert in Pediatric Anesthesia.
#      18 Your primary task is to generate high-quality Korean Q&A data from provided medical guidelines for training a medical question-answering model.
#      19
#      20 # Core Principles
#      21 - Maintain strict medical accuracy and precision
#      22 - Focus on practical clinical scenarios
#      23 - Ensure questions are specific and actionable
#      24 - Include relevant numerical values when available
#      25 - Generate questions only from provided context
#      26 - Use clear and professional Korean language
#      27
#      28 # Input Data Structure
#      29 {
#      30     "context": {context},
#      31     "num_questions per page": {num_questions}
#      32 }
#      33
#      34 # Question Generation Guidelines
#      35 1. Content Adherence:
#      36    - Generate questions strictly based on provided content
#      37    - Include specific numerical values (doses, weights, ages, etc.)
#      38    - Focus on practical clinical applications
#      39
#      40 2. Question Format:
#      41    - Use open-ended, short-answer format
#      42    - Write questions in Korean
#      43    - Make questions specific and clinically relevant
#      44    - Avoid multiple-choice formats
#      45
#      46 3. Reference Requirements:
#      47    - Include all supporting sentences
#      48    - For tables: include entire table content
#      49    - For figures: include surrounding text and captions
#      50
#      51 # Answer Guidelines
#      52 - Start reasoning directly with a quote
#      53 - Start with a step-by-step reasoning using quotes from the context
#      54 - Enclose all direct quotes in **##begin_quote## ... ##end_quote##**
#      55 - End with `<ANSWER>: ...` in Korean (full sentence)
#      56
#      57 # Output Format
#      58 Return your output in this **strict JSON format**:
#      59 [
#      60   {
#      61     "question": "한국어로 된 의학 질문",
#      62     "reference_sentences": [
#      63       "관련 문장 1",
#      64       "관련 문장 2"
#      65     ],
#      66     "answer": "##Reason: ...\n<ANSWER>: ..."
#      67   }
#      68 ]
#      69
#      70 # Quality Controls
#      71 - Ensure medical accuracy
#      72 - Verify all numerical values
#      73 - Check Korean language usage
#      74 - Validate JSON format
#      75 - Confirm reference alignment
#      76
#      77 # Error Prevention
#      78 - Double-check medical terminology
#      79 - Verify numerical calculations
#      80 - Ensure proper Korean grammar
#      81 - Validate JSON structure
#      82 - Confirm context alignment
#      83
#      84 # Example Outputs
#      85 Return as a **valid JSON array** of objects. Each object must look like:
#      86
#      87 [
#      88   {{
#      89     "question": "5살 23kg 소아 환자의 마취 중 적절한 수액 주입량은?",
#      90     "reference_sentences": [
#      91       "20kg을 초과하는 소아의 유지 수액량은 첫 20kg에 대해 1500mL를 적용하고, 이후 1kg당 20mL를 추가로 계산한다.",
#      92       "이 수액량은 전신마취 중 적절한 수분 공급을 위해 사용된다."
#      93     ],
#      94     "answer": "##Reason: 문서의 ##begin_quote## 20kg을 초과하는 소아의 유지 수액량은 첫 20kg에 대해 1500mL를 적용하고, 이후 1kg당 20mL를 추가로 계산한다 ##end_quote## 라는 설명에 따르면, 23kg 소아는 1500mL + (3×20mL) = 1560mL가 필요합니다.\n<ANSWER>: 5살 23kg 소아의 마취 중 유지 수액량은 1560mL입니다."
#      95   }},
#      96   {{
#      97     "question": "소아 환자를 깨울 때 laryngospasm이 의심되면 어떤 처치를 해야 하나요?",
#      98     "reference_sentences": [
#      99       "Laryngospasm이 의심되는 경우 즉각적인 처치로는 jaw thrust, 양압 환기, 그리고 succinylcholine 투여가 포함된다.",
#     100       "신속한 인식과 처치가 저산소증을 예방하는 데 중요하다."
#     101     ],
#     102     "answer": "##Reason: 문서에 따르면 ##begin_quote## 즉각적인 처치로는 jaw thrust, 양압 환기, 그리고 succinylcholine 투여가 포함된다 ##end_quote## 라고 되어 있습니다. 이는 환자의 기도를 유지하고 저산소증을 방지하는 데 중요한 조치입니다.\n<ANSWER>: Laryngospasm이 의심되는 경우 jaw thrust, 양압 환기, succinylcholine 투여를 포함한 즉각적인 처치가 필요합니다."
#     103   }}
#     104 ]
#     105 """
#     106 )
#
# TypeError: PromptTemplate.from_template() missing 1 required positional argument: 'template'

# %%
# ✅ 2. LLM 설정
llm = ChatOpenAI(
    model="gpt-4.1",
    temperature=0.3,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()],
)

# %%
# ✅ 3. JSON 파서
def custom_json_parser(response):
    try:
        json_string = response.content.strip().removeprefix("```json\n").removesuffix("\n```").strip()
        json_string = f'[{json_string}]' if not json_string.startswith("[") else json_string
        return json.loads(json_string)
    except Exception as e:
        print(f"[PARSE ERROR] {e}")
        return []

# %%
# ✅ 4. 체인 구성
raft_chain = medical_qa_prompt_template | llm | RunnableLambda(custom_json_parser)

# ✅ 5. QA 생성
qa_dataset = []
question_set = set()
output_path = "qa_dataset.jsonl"
invalid_log_path = "qa_invalid_outputs.jsonl"

open(output_path, "w", encoding="utf-8").close()
open(invalid_log_path, "w", encoding="utf-8").close()

progress = tqdm(total=len(split_docs))
progress.set_description("QA 생성 중")

for doc_idx, doc in enumerate(split_docs):
    context = doc.page_content.strip()
    metadata = doc.metadata or {}
    page = metadata.get("page", -1)

    if not context or len(context) < 100:
        print(f"[SKIPPED: empty/short context] page={page}")
        progress.update(1)
        continue

    llm.temperature = 0.2 if doc_idx % 2 == 0 else 0.5

    try:
        results = raft_chain.invoke({
            "context": context,
            "num_questions": 4
        })
    except Exception as e:
        print(f"[ERROR: GPT 호출 실패] page={page}, error={e}")
        progress.update(1)
        continue

    valid_count = 0
    for qa in results:
        question = qa.get("question", "").strip()
        answer = qa.get("answer", "").strip()
        references = qa.get("reference_sentences", [])

        if not question or any(difflib.SequenceMatcher(None, question, q).ratio() > 0.85 for q in question_set):
            continue

        if not re.match(r"^##Reason: .*<ANSWER>: .*", answer, re.DOTALL):
            print(f"[SKIPPED: answer format invalid] {question}")
            with open(invalid_log_path, "a", encoding="utf-8") as f:
                json.dump({"issue": "invalid_answer_format", "question": question, "answer": answer}, f, ensure_ascii=False)
                f.write("\n")
            continue

        question_set.add(question)
        qa["metadata"] = metadata
        qa_dataset.append(qa)

        with open(output_path, "a", encoding="utf-8") as f:
            f.write(json.dumps(qa, ensure_ascii=False) + "\n")

        valid_count += 1
        if valid_count >= 5:
            break

    progress.update(1)

progress.close()
print(f"\n✅ 생성 완료! 총 {len(qa_dataset)}개의 QA 생성됨.")

# ✅ 엑셀로 저장
rows = []
for item in qa_dataset:
    rows.append({
        "page": item.get("metadata", {}).get("page"),
        "question": item.get("question"),
        "reference_sentences": "\n".join(item.get("reference_sentences", [])),
        "answer": item.get("answer"),
    })

df = pd.DataFrame(rows)
excel_output_path = r"/Users/daeunbaek/nuebaek/BOAZ/Daeun/raft_qa_dataset_1.xlsx"
df.to_excel(excel_output_path, index=False)
print(f"✅ 엑셀 파일 저장 완료: {excel_output_path}")
# Out:
# QA 생성 중:   0%|          | 0/6 [00:00<?, ?it/s]
# [
#   {
#     "question": "한국 소아마취과 의사들이 소아의 수술 전 불안 완화를 위해 가장 많이 사용하는 약물은 무엇입니까?",
#     "reference_sentences": [
#       "Nearly half of the respondents (53.7%) used premedication to reduce anxiety, and midazolam was most frequently used.",
#       "Anesthesiologists requiring effective anxiety reduction prefer pharmacological intervention and most commonly use intravenous midazolam,"
#     ],
#     "answer": "##Reason: 문맥에서 'Nearly half of the respondents (53.7%) used premedication to reduce anxiety, and midazolam was most frequently used.'와 'Anesthesiologists requiring effective anxiety reduction prefer pharmacological intervention and most commonly use intravenous midazolam,'라는 문장을 통해 소아마취과 의사들이 불안 완화를 위해 가장 많이 사용하는 약물이 미다졸람임을 알 수 있습니다.\n<ANSWER>: 한국 소아마취과 의사들은 소아의 수술 전 불안 완화를 위해 미다졸람을 가장 많이 사용합니다."
#   },
#   {
#     "question": "한국 소아마취과 의사들이 비약물적 불안 완화 방법 중 가장 효과적이라고 생각하는 방법은 무엇이며, 실제로 몇 퍼센트가 이를 허용합니까?",
#     "reference_sentences": [
#       "Parental presence during induction of anesthesia was considered the most effective non-pharmacological intervention (60.4%), and was allowed by 78% of respondents,"
#     ],
#     "answer": "##Reason: 'Parental presence during induction of anesthesia was considered the most effective non-pharmacological intervention (60.4%), and was allowed by 78% of respondents,'라는 문장에서 소아마취과 의사들이 비약물적 불안 완화 방법 중 가장 효과적이라고 생각하는 방법이 마취 유도 시 부모 동반임을 알 수 있고, 실제로 78%가 이를 허용함을 알 수 있습니다.\n<ANSWER>: 한국 소아마취과 의사들은 마취 유도 시 부모 동반을 가장 효과적인 비약물적 불안 완화 방법으로 생각하며, 78%가 이를 허용합니다."
#   },
#   {
#     "question": "한국 소아마취과 의사들이 소아의 수술 전 불안 완화를 위해 약물적 또는 비약물적 중재를 실제로 시행하는 비율은 얼마입니까?",
#     "reference_sentences": [
#       "In clinical practice, 90% of respondents used pharmacological and/or non-pharmacological intervention to alleviate anxiety in children."
#     ],
#     "answer": "##Reason: 'In clinical practice, 90% of respondents used pharmacological and/or non-pharmacological intervention to alleviate anxiety in children.'라는 문장에서 실제로 90%의 소아마취과 의사들이 약물적 또는 비약물적 중재를 시행함을 알 수 있습니다.\n<ANSWER>: 한국 소아마취과 의사들의 90%가 소아의 수술 전 불안 완화를 위해 약물적 또는 비약물적 중재를 실제로 시행합니다."
#   },
#   {
#     "question": "한국 소아마취과 의사들이 소아의 수술 전 불안 완화 중재를 시행할 때 공식적인 병원 지침에 따라 시행하는 비율은 얼마입니까?",
#     "reference_sentences": [
#       "Only 4.9% of respondents undertook anxiety reduction according to a written hospital policy, and 95.1% did not.",
#       "Most respondents (70.7%) performed anxiolytic intervention guided by informally standardized hospital protocol."
#     ],
#     "answer": "##Reason: 'Only 4.9% of respondents undertook anxiety reduction according to a written hospital policy, and 95.1% did not.'라는 문장에서 공식적인 병원 지침에 따라 불안 완화 중재를 시행하는 비율이 4.9%임을 알 수 있습니다.\n<ANSWER>: 한국 소아마취과 의사들 중 공식적인 병원 지침에 따라 소아의 수술 전 불안 완화 중재를 시행하는 비율은 4.9%입니다."
#   }
# ]
# QA 생성 중:  17%|█▋        | 1/6 [00:21<01:49, 21.88s/it]
# [
#   {
#     "question": "설문에 참여한 소아마취과 의사들의 평균 임상 경력은 몇 년이며, 표준편차와 범위를 함께 설명하세요.",
#     "reference_sentences": [
#       "They had been in practice for 14.4 ± 8.4 years.",
#       "Years in practice | Mean ± SD | 14.4 ± 8.4 | | | Range | 1–32 |"
#     ],
#     "answer": "##Reason: 설문에 참여한 소아마취과 의사들의 임상 경력에 대해 'They had been in practice for 14.4 ± 8.4 years.'와 'Years in practice | Mean ± SD | 14.4 ± 8.4 | | | Range | 1–32 |'에서 평균이 14.4년, 표준편차가 8.4년, 범위는 1년에서 32년임을 알 수 있습니다.\n<ANSWER>: 설문에 참여한 소아마취과 의사들의 평균 임상 경력은 14.4년이며, 표준편차는 8.4년이고, 경력 범위는 1년에서 32년입니다."
#   },
#   {
#     "question": "설문에 응답한 소아마취과 의사들의 연령 분포를 구체적으로 설명하세요.",
#     "reference_sentences": [
#       "Respondents were typically in their forties (39%), ...",
#       "| Age (yr) | 31–40 | 10 (24.4) | | | 41–50 | 16 (39.0) | | | 51–60 | 13 (31.7) | | | 61–70 | 2 (4.9) |"
#     ],
#     "answer": "##Reason: 'Respondents were typically in their forties (39%)'와 표의 연령 분포에서 31–40세가 24.4%(10명), 41–50세가 39.0%(16명), 51–60세가 31.7%(13명), 61–70세가 4.9%(2명)임을 확인할 수 있습니다.\n<ANSWER>: 설문에 응답한 소아마취과 의사들의 연령 분포는 31–40세가 24.4%, 41–50세가 39.0%, 51–60세가 31.7%, 61–70세가 4.9%입니다."
#   },
#   {
#     "question": "설문 응답자의 근무 병원 종류와 각 비율을 설명하세요.",
#     "reference_sentences": [
#       "Most of them (85.4%) worked at tertiary hospital.",
#       "| Type of hospital | Primary | 1 (2.4) | | | Secondary | 5 (12.2) | | | Tertiary | 35 (85.4) |"
#     ],
#     "answer": "##Reason: 'Most of them (85.4%) worked at tertiary hospital.'와 표에서 1차 병원이 2.4%(1명), 2차 병원이 12.2%(5명), 3차 병원이 85.4%(35명)임을 알 수 있습니다.\n<ANSWER>: 설문 응답자의 85.4%가 3차 병원, 12.2%가 2차 병원, 2.4%가 1차 병원에서 근무하고 있습니다."
#   },
#   {
#     "question": "설문에 참여한 소아마취과 의사들이 마취 전 불안 감소를 위한 병원 내 서면 지침을 갖추고 있는 비율은 얼마입니까?",
#     "reference_sentences": [
#       "Most respondents (95.1%) had no written hospital policy; only 4.9% of the respondent performed reduction of child for"
#     ],
#     "answer": "##Reason: 'Most respondents (95.1%) had no written hospital policy; only 4.9% of the respondent performed reduction of child for'에서 95.1%가 서면 지침이 없고, 4.9%만이 서면 지침이 있음을 알 수 있습니다.\n<ANSWER>: 설문에 참여한 소아마취과 의사 중 4.9%만이 마취 전 불안 감소를 위한 병원 내 서면 지침을 갖추고 있습니다."
#   }
# ]
# QA 생성 중:  33%|███▎      | 2/6 [00:33<01:04, 16.06s/it]
# [
#   {
#     "question": "소아 환자에서 수술 전 불안 감소를 위해 비약물적 중재와 전처치 중 어느 것이 더 선호되며, 그 이유는 무엇입니까?",
#     "reference_sentences": [
#       "Non-pharmacological intervention (46.3%) was preferred to premedication (39.0%) to reduce preoperatively anxiety. Small proportion of respondents (14.6%) stated they had no preference.",
#       "The three most common reasons given to support preference were effectiveness (32.0%), concern about side effects (26.0%), and convenience (24.0%, Table 3). However, these reasons were found to depend on anxiolytic preferences, that is, effectiveness was favored by those who preferred pharmacological intervention, and concern about side effects was favored by those who preferred non-pharmacological intervention.",
#       "Table 3. Reasons for Anxiolytic Intervention Preferences in Pediatric Patients |  | Non-pharmacological | Pharmacological preference | No preference | Overall | | --- | --- | --- | --- | --- | |  | preference (n = 19) | (n = 16) | (n = 6) | (n = 41) | | Effectiveness | 5 (17.9) | 11 (68.8) | 0 | 16 (32.0) | | Concern about side effect | 10 (35.7) | 0 | 3 (50.0) | 13 (26.0) | | Convenience | 7 (25.0) | 4 (25.0) | 1 (16.7) | 12 (24.0) | | Reduction of parental anxiety | 5 (17.9) | 1 (6.3) | 1 (16.7) | 7 (14.0) | | Psychological stability of anesthesiologist | 1 (3.5) | 0 | 1 (16.7) | 2 (4.0) | | All responses | 28 (100) | 16 (100) | 6 (100) | 50 (100) | Multiple responses are possible. Values are expressed as number (%) of all responses."
#     ],
#     "answer": "##Reason: 문맥에 따르면, 'Non-pharmacological intervention (46.3%) was preferred to premedication (39.0%) to reduce preoperatively anxiety.'라고 하여 비약물적 중재가 전처치보다 더 선호되는 것으로 나타났습니다. 또한, 'The three most common reasons given to support preference were effectiveness (32.0%), concern about side effects (26.0%), and convenience (24.0%, Table 3).'라고 하여 효과, 부작용에 대한 우려, 편의성이 주요 이유임을 알 수 있습니다. 표 3에서는 비약물적 중재를 선호하는 경우 부작용에 대한 우려(35.7%)가 가장 많았고, 약물적 중재를 선호하는 경우 효과(68.8%)가 가장 많았습니다.\n<ANSWER>: 소아 환자에서 수술 전 불안 감소를 위해 비약물적 중재가 전처치보다 더 선호되며, 주요 이유는 부작용에 대한 우려와 편의성, 그리고 효과입니다."
#   },
#   {
#     "question": "실제 임상에서 소아 환자 불안 감소를 위해 비약물적 중재와 약물적 전처치가 각각 얼마나 자주 사용되고 있습니까?",
#     "reference_sentences": [
#       "Actually used intervention for reducing anxiety in clinical practice were significantly different according to the anxiolytic preference (P = 0.005) but they did not consistently match each other (Table 4). Overall, non-pharmacological intervention and premedication were actually performed by 36.6 and 24.4% of the respondents, respectively, in clinical practice. Both were used by 29.3% and neither was used by 9.8% of the respondents.",
#       "Table 4. Preference and Actual Practice of Anxiolytic Interventionin Pediatric Anesthesia | Actual practice | Non-pharmacological preference (n = 19) | Pharmacological preference (n = 16) | No preference (n = 6) | Overall (n = 41) | | --- | --- | --- | --- | --- | | Non-pharmacological intervention | 12 (63.2) | 2 (12.5) | 1 (16.7) | 15 (36.6) | | Pharmacological intervention | 1 (5.3) | 8 (50.0) | 1 (16.7) | 10 (24.4) | | Both | 5 (26.3) | 4 (25.0) | 3 (50) | 12 (29.3) | | Neither | 1 (5.3) | 2 (12.5) | 1 (16.7) | 4 (9.8) | Values are expressed as numbers (%) of respondents."
#     ],
#     "answer": "##Reason: 문맥에 따르면, 'Overall, non-pharmacological intervention and premedication were actually performed by 36.6 and 24.4% of the respondents, respectively, in clinical practice. Both were used by 29.3% and neither was used by 9.8% of the respondents.'라고 하여 실제 임상에서의 사용 빈도를 알 수 있습니다. 표 4에서도 전체 응답자 중 비약물적 중재는 36.6%, 약물적 전처치는 24.4%에서 실제로 시행되고 있음을 확인할 수 있습니다.\n<ANSWER>: 실제 임상에서 소아 환자 불안 감소를 위해 비약물적 중재는 36.6%, 약물적 전처치는 24.4%의 빈도로 사용되고 있습니다."
#   },
#   {
#     "question": "소아 환자에서 전처치 약물 사용 시 적용되는 최소 연령은 어떻게 되며, 가장 많이 채택된 연령 기준은 무엇입니까?",
#     "reference_sentences": [
#       "Age limitation to premedication was applied by 39.0% of respondents. Although minimum age for premedication ranged from 1 month to 5 years, majority of respondents (68.8%) adopted a minimum age of 1 year."
#     ],
#     "answer": "##Reason: 문맥에 따르면, 'Age limitation to premedication was applied by 39.0% of respondents. Although minimum age for premedication ranged from 1 month to 5 years, majority of respondents (68.8%) adopted a minimum age of 1 year.'라고 하여 전처치 약물 사용 시 최소 연령이 1개월에서 5세까지 다양하게 적용되지만, 가장 많이 채택된 기준은 1세임을 알 수 있습니다.\n<ANSWER>: 소아 환자에서 전처치 약물 사용 시 최소 연령은 1개월에서 5세까지 다양하지만, 응답자의 68.8%가 1세를 최소 연령으로 채택하고 있습니다."
#   },
#   {
#     "question": "소아 환자에서 전처치 약물 사용을 선호하지 않는 주요 이유는 무엇입니까?",
#     "reference_sentences": [
#       "However, the other respondents (46.3%) stated they were unlikely to use premedication in practice because of needlessness of premedication (42.1%), concern about side effects (31.5%) and invasiveness of administration (21.5%)."
#     ],
#     "answer": "##Reason: 문맥에 따르면, 'the other respondents (46.3%) stated they were unlikely to use premedication in practice because of needlessness of premedication (42.1%), concern about side effects (31.5%) and invasiveness of administration (21.5%).'라고 하여 전처치 약물 사용을 선호하지 않는 주요 이유가 명확히 제시되어 있습니다.\n<ANSWER>: 소아 환자에서 전처치 약물 사용을 선호하지 않는 주요 이유는 필요성 부족(42.1%), 부작용에 대한 우려(31.5%), 투여의 침습성(21.5%)입니다."
#   }
# ]
# QA 생성 중:  50%|█████     | 3/6 [00:54<00:53, 17.98s/it]
# [
#   {
#     "question": "소아 선택적 수술 전 가장 많이 사용되는 전처치 약물과 그 사용 빈도는 얼마입니까?",
#     "reference_sentences": [
#       "Of all responses, the most frequently used premedication was midazolam (24.7%) followed by ketamine (20.3%) when multiple responses were allowed by the respondent (Table 5).",
#       "Table 5. Premedication of Pediatric Patients before Elective Surgery",
#       "| Premedication | Route | Number (%) |",
#       "| --- | --- | --- |",
#       "| Midazolam | IV | 19 (21.3) |",
#       "|  | IM | 3 (3.4) |",
#       "| Ketamine | IV | 15 (16.9) |",
#       "|  | IM | 3 (3.4) |",
#       "| Glycopyrrolate | IV | 14 (15.7) |",
#       "|  | IM | 4 (4.5) |",
#       "| Atropine | IV | 9 (10.1) |",
#       "|  | IM | 3 (3.4) |",
#       "| Thiopental | IV | 8 (9.0) |",
#       "| Propofol | IV | 3 (3.4) |",
#       "| Diazepam | IV | 1 (1.1) |",
#       "| Fentanyl | IV | 4 (4.5) |",
#       "| Dexmedetomidine | IV | 2 (2.2) |",
#       "| Meperidine | IV | 1 (1.1) |",
#       "| All responses |  | 89 (100) |",
#       "Multiple responses are possible. Values are expressed as numbers (%) of all responses."
#     ],
#     "answer": "##Reason: 문맥에서 'Of all responses, the most frequently used premedication was midazolam (24.7%) followed by ketamine (20.3%) when multiple responses were allowed by the respondent (Table 5).'라고 명시되어 있고, Table 5에서 midazolam이 24.7%로 가장 많이 사용됨을 알 수 있습니다. ##end_quote##\n<ANSWER>: 소아 선택적 수술 전 가장 많이 사용되는 전처치 약물은 미다졸람이며, 사용 빈도는 24.7%입니다."
#   },
#   {
#     "question": "소아 수술 전 항콜린성 전처치제의 사용 빈도에 대한 임상의들의 의견 분포는 어떻게 됩니까?",
#     "reference_sentences": [
#       "The use of anticholinergic premedication for children undergoing surgery was considered routinely by 24.4%, occasionally by 34.1% and as unnecessary by 39.0% of the respondents."
#     ],
#     "answer": "##Reason: 문맥에 따르면 'The use of anticholinergic premedication for children undergoing surgery was considered routinely by 24.4%, occasionally by 34.1% and as unnecessary by 39.0% of the respondents.'라고 명확하게 비율이 제시되어 있습니다. ##end_quote##\n<ANSWER>: 소아 수술 전 항콜린성 전처치제 사용에 대해 24.4%는 일상적으로 사용, 34.1%는 가끔 사용, 39.0%는 불필요하다고 응답하였습니다."
#   },
#   {
#     "question": "전처치 약물 투여 경로로 정맥 주사와 근육 주사 중 어떤 경로가 더 선호되며, 각각의 약물별 투여 빈도를 알려주세요.",
#     "reference_sentences": [
#       "Intravenous administration was usually preferred to intramuscular administration.",
#       "Table 5. Premedication of Pediatric Patients before Elective Surgery",
#       "| Premedication | Route | Number (%) |",
#       "| --- | --- | --- |",
#       "| Midazolam | IV | 19 (21.3) |",
#       "|  | IM | 3 (3.4) |",
#       "| Ketamine | IV | 15 (16.9) |",
#       "|  | IM | 3 (3.4) |",
#       "| Glycopyrrolate | IV | 14 (15.7) |",
#       "|  | IM | 4 (4.5) |",
#       "| Atropine | IV | 9 (10.1) |",
#       "|  | IM | 3 (3.4) |",
#       "| Thiopental | IV | 8 (9.0) |",
#       "| Propofol | IV | 3 (3.4) |",
#       "| Diazepam | IV | 1 (1.1) |",
#       "| Fentanyl | IV | 4 (4.5) |",
#       "| Dexmedetomidine | IV | 2 (2.2) |",
#       "| Meperidine | IV | 1 (1.1) |",
#       "| All responses |  | 89 (100) |"
#     ],
#     "answer": "##Reason: 문맥에서 'Intravenous administration was usually preferred to intramuscular administration.'라고 하였으며, Table 5에서 각 약물별로 IV(정맥)와 IM(근육) 투여 빈도가 구체적으로 제시되어 있습니다. ##end_quote##\n<ANSWER>: 전처치 약물 투여 경로로는 정맥 주사가 근육 주사보다 더 선호되며, 예를 들어 미다졸람은 IV 21.3%, IM 3.4%, 케타민은 IV 16.9%, IM 3.4% 등으로 나타났습니다."
#   },
#   {
#     "question": "소아 전처치 약물 사용 시 가장 우려되는 부작용과 실제로 가장 자주 경험하는 부작용은 무엇입니까?",
#     "reference_sentences": [
#       "Respiratory depression was the side effect of most concern (53.7%) when considering use of premedication, and was also the most commonly experienced side effect (22.0%). Other side effects actually experienced by respondents were overexcitement (14.6%), injection pain (12.2%), delayed recovery after anesthesia (9.8%), and nausea and vomiting (2.4%). However, 20% of respondents report no adverse event after premedication."
#     ],
#     "answer": "##Reason: 문맥에서 'Respiratory depression was the side effect of most concern (53.7%) when considering use of premedication, and was also the most commonly experienced side effect (22.0%).'라고 명확히 기술되어 있습니다. ##end_quote##\n<ANSWER>: 소아 전처치 약물 사용 시 가장 우려되는 부작용과 실제로 가장 자주 경험하는 부작용은 모두 호흡억제(Respiratory depression)입니다."
#   }
# ]
# QA 생성 중:  67%|██████▋   | 4/6 [01:11<00:35, 17.79s/it]
# [
#   {
#     "question": "한국에서 소아 마취 전 불안 완화를 위한 약물 전처치의 시행률은 얼마이며, 이는 다른 국가들과 어떻게 비교됩니까?",
#     "reference_sentences": [
#       "In Korea, the sedative premedication rate for pediatric anesthesia (54.7%), as determined by the present study, is similar to those reported in Turkey, Germany, and the United States [5,9,10], but is much higher than reported in the United Kingdom for day-case surgery (19%) [7]."
#     ],
#     "answer": "##Reason: 문맥에서는 한국의 소아 마취 전 진정제 전처치 시행률이 54.7%임을 명시하고 있으며, 이는 터키, 독일, 미국과 비슷하지만 영국의 당일 수술 시행률(19%)보다는 훨씬 높다고 설명하고 있습니다.\n<ANSWER>: 한국에서 소아 마취 전 진정제 전처치 시행률은 54.7%이며, 이는 터키, 독일, 미국과 비슷하지만 영국의 당일 수술 시행률(19%)보다는 훨씬 높습니다."
#   },
#   {
#     "question": "한국에서 소아 마취 전 불안 완화에 가장 많이 사용되는 약물은 무엇이며, 투여 경로는 어떻게 됩니까?",
#     "reference_sentences": [
#       "Although numerous drugs have been used in clinical practice, midazolam is currently the mainstay of sedative premedication for pediatric anesthesia.",
#       "Because oral or intranasal midazolam, commonly used as a premedication in Europe and the US [5,9], is not currently available in Korea, respondents mostly administered midazolam intravenously in the preoperative holding area."
#     ],
#     "answer": "##Reason: 문맥에 따르면, 다양한 약물이 임상에서 사용되고 있지만 현재 소아 마취 전 진정제 전처치의 주된 약물은 미다졸람이며, 경구 또는 비강 투여가 불가능하여 주로 수술 전 대기실에서 정맥주사로 투여한다고 명시되어 있습니다.\n<ANSWER>: 한국에서 소아 마취 전 불안 완화에 가장 많이 사용되는 약물은 미다졸람이며, 주로 정맥주사로 투여됩니다."
#   },
#   {
#     "question": "소아 마취 전 진정제 전처치의 가장 흔한 부작용은 무엇이며, 이로 인해 어떤 임상적 조치가 취해집니까?",
#     "reference_sentences": [
#       "Respiratory depression was the most commonly experienced side effect of premedication, and was the main reason for avoiding sedative premedication in children and for administering premedication in preoperative holding areas equipped with sufficient resources to monitor and manage side effects rather than in ward.",
#       "We presume that fear for respiratory depression (the most serious side effect of premedication) caused the majority of respondents to forbid the premedication of children less than 1 year old."
#     ],
#     "answer": "##Reason: 문맥에서는 진정제 전처치의 가장 흔한 부작용이 호흡억제임을 명확히 밝히고 있으며, 이로 인해 부작용을 모니터링하고 관리할 수 있는 수술 전 대기실에서 전처치를 시행하거나 1세 미만 소아에게는 전처치를 금지하는 경향이 있음을 설명하고 있습니다.\n<ANSWER>: 소아 마취 전 진정제 전처치의 가장 흔한 부작용은 호흡억제이며, 이로 인해 부작용을 관리할 수 있는 수술 전 대기실에서 전처치를 시행하거나 1세 미만 소아에게는 전처치를 금지하는 임상적 조치가 취해집니다."
#   },
#   {
#     "question": "한국 소아마취과 의사들이 비약물적 불안 완화 중 가장 선호하는 방법은 무엇이며, 이에 대한 국내외 의견 차이는 무엇입니까?",
#     "reference_sentences": [
#       "PPIA was the most frequently employed non-pharmacological intervention by respondents.",
#       "In our survey, 78.0% of respondents agree with PPIA and 19.5% allowed routine PPIA.",
#       "On the other hand, 50% of American anesthesiologists forbade PPIA [9], and most anesthesiologists in the UK and Canada allowed PPIA [14-16]. Discrepancies between countries may be due to the use of different induction techniques, legal implications, and economic issues, such as, operating room efficiency."
#     ],
#     "answer": "##Reason: 문맥에 따르면, 한국 소아마취과 의사들이 가장 많이 사용하는 비약물적 불안 완화 방법은 PPIA(부모 동반 마취 유도)이며, 78%가 동의하고 19.5%는 일상적으로 허용한다고 명시되어 있습니다. 미국에서는 50%가 금지하는 반면, 영국과 캐나다에서는 대부분 허용한다고 하여 국가 간 의견 차이가 있음을 설명합니다.\n<ANSWER>: 한국 소아마취과 의사들이 가장 선호하는 비약물적 불안 완화 방법은 부모 동반 마취 유도(PPIA)이며, 미국에서는 절반이 금지하는 반면 영국과 캐나다에서는 대부분 허용하는 등 국가별로 의견 차이가 있습니다."
#   }
# ]
# QA 생성 중:  83%|████████▎ | 5/6 [01:31<00:18, 18.66s/it]
# [
#   {
#     "question": "소아 마취에서 불안 감소를 위해 가장 선호되는 비약물적 중재 방법은 무엇입니까?",
#     "reference_sentences": [
#       "wanting safe reduction of anxiety preferred non-pharmacological intervention and most frequently used parental presence during induction the anesthesia."
#     ],
#     "answer": "##Reason: 문맥에서 'wanting safe reduction of anxiety preferred non-pharmacological intervention and most frequently used parental presence during induction the anesthesia.'라고 명시되어 있습니다. 이는 소아 마취에서 불안 감소를 위해 비약물적 중재가 선호되며, 그 중에서도 마취 유도 시 부모의 동반이 가장 많이 사용된다는 의미입니다.\n<ANSWER>: 소아 마취에서 불안 감소를 위해 가장 선호되는 비약물적 중재는 마취 유도 시 부모의 동반입니다."
#   },
#   {
#     "question": "소아 마취에서 비약물적 불안 감소 중재로 부모 동반이 사용되는 시기는 언제입니까?",
#     "reference_sentences": [
#       "wanting safe reduction of anxiety preferred non-pharmacological intervention and most frequently used parental presence during induction the anesthesia."
#     ],
#     "answer": "##Reason: 문장에 따르면, 'parental presence during induction the anesthesia'라고 되어 있어, 부모의 동반이 마취 유도 시기에 사용된다는 것을 알 수 있습니다.\n<ANSWER>: 소아 마취에서 비약물적 불안 감소 중재로 부모 동반은 마취 유도 시에 사용됩니다."
#   },
#   {
#     "question": "소아 마취에서 불안 감소를 위한 비약물적 중재가 선호되는 이유는 무엇입니까?",
#     "reference_sentences": [
#       "wanting safe reduction of anxiety preferred non-pharmacological intervention and most frequently used parental presence during induction the anesthesia."
#     ],
#     "answer": "##Reason: 문맥에서 'wanting safe reduction of anxiety preferred non-pharmacological intervention'라는 표현을 통해, 안전한 불안 감소를 위해 비약물적 중재가 선호된다고 되어 있습니다. 이는 약물의 부작용 없이 불안을 줄이려는 임상적 목적을 반영합니다.\n<ANSWER>: 소아 마취에서 불안 감소를 위한 비약물적 중재가 선호되는 이유는 안전하게 불안을 줄일 수 있기 때문입니다."
#   },
#   {
#     "question": "소아 마취 유도 시 부모의 동반이 가장 많이 사용된다는 사실을 뒷받침하는 문헌은 무엇입니까?",
#     "reference_sentences": [
#       "wanting safe reduction of anxiety preferred non-pharmacological intervention and most frequently used parental presence during induction the anesthesia.",
#       "- 9. Kain ZN, Caldwell-Andrews AA, Krivutza DM, Weinberg ME, Wang SM, Gaal D. Trends in the practice of parental presence during induction of anesthesia and the use of preoperative sedative premedication in the United States, 1995-2002: results of a follow-up national survey. Anesth Analg 2004; 98: 1252-9.",
#       "- 15. Roman DE, Barker I, Reilly CS. Anaesthetists' attitudes to parental presence at induction of general anaesthesia in children. Anaesthesia 1993; 48: 338-40.",
#       "- 16. Kain ZN, Ferris CA, Mayes LC, Rimar S. Parental presence during induction of anaesthesia: practice differences between the United States and Great Britain. Paediatr Anaesth 1996; 6: 187-93."
#     ],
#     "answer": "##Reason: 문맥에서 'most frequently used parental presence during induction the anesthesia.'라고 기술되어 있고, 이를 뒷받침하는 문헌으로 9번, 15번, 16번 참고문헌이 제시되어 있습니다.\n<ANSWER>: 소아 마취 유도 시 부모의 동반이 가장 많이 사용된다는 사실은 9번, 15번, 16번 참고문헌에서 뒷받침되고 있습니다."
#   }
# ]
# QA 생성 중: 100%|██████████| 6/6 [01:46<00:00, 17.68s/it]
# ✅ 생성 완료! 총 24개의 QA 생성됨.
# ✅ 엑셀 파일 저장 완료: /Users/daeunbaek/nuebaek/BOAZ/Daeun/raft_qa_dataset_1.xlsx
